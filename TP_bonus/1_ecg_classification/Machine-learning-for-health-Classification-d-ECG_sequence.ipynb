# %% [markdown]
# # ECG classification
#
# Laurent Cetinsoy - Datadidacte

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A first naive model by extracting simple features

# %% [markdown]
# Your environment contains variables arr, nsr, and chf which respectively contain 10-second recordings of ECG signals extracted from three datasets on PhysioNet: one from a person suffering from arrhythmia, one from a person with a normal heart rhythm, and another from a person with heart failure.
#
#
# Matplotlib  subplots (or any other library), display these signals on three subfigures (the subplots should be called with the parameter nrows = 3).
# Can you find any differences between them?

# %%
arr = np.loadtxt('arr.txt')
chf = np.loadtxt('chf.txt')
nsr = np.loadtxt('nsr.txt')

# %%
def plot_ecg_signals(arr, chf, nsr):
    _, axs = plt.subplots(nrows=3, figsize=(12, 8))

    time = np.linspace(0, 10, len(arr))
    axs[0].plot(time, arr, label='Arrhythmia')
    axs[0].set_title('ECG signal - Arrhythmia')
    axs[0].set_xlabel('Time (seconds)')
    axs[0].set_ylabel('Amplitude')
    axs[0].legend()

    time = np.linspace(0, 10, len(chf))
    axs[1].plot(time, chf, label='Heart failure', color='orange')
    axs[1].set_title('ECG signal - Heart Failure')
    axs[1].set_xlabel('Time (seconds)')
    axs[1].set_ylabel('Amplitude')
    axs[1].legend()

    time = np.linspace(0, 10, len(nsr))
    axs[2].plot(time, nsr, label='Normal sinus rhythm', color='green')
    axs[2].set_title('ECG signal - Normal sinus rhythm')
    axs[2].set_xlabel('Time (seconds)')
    axs[2].set_ylabel('Amplitude')
    axs[2].legend()

    plt.tight_layout()
    plt.show()

# %%
plot_ecg_signals(arr, chf, nsr)

# %% [markdown]
# **Answer:**
# > We can see that the signals are different (in terms of shape) but have the same period T (approximately) corresponding to the beat of a heart.

# %% [markdown]
# We want to extract features from the time series. For that we will use simple statistics.
#
#
# Create a function named calculate_stats_features(x) that calculates some statistical features of a signal x using standard numpy functions: nanpercentile, nanmean, etc.
# calculate_stats_features will return a list of features in this order:
#
# 0. Max
# 1. Min
# 2. Mean
# 3. Median
# 4. Variance

# %%
def calculate_stats_features(x):
    return np.nanmax(x), np.nanmin(x), np.nanmean(x), np.nanmedian(x), np.nanvar(x)

# Test
calculate_stats_features([1, 2, 3, 4])
# Out:
# (4, 1, 2.5, 2.5, 1.25)

# %% [markdown]
# Create a function named `calculate_zero_crossing(x)` that calculates the Zero
# Crossing of a signal x.
#
# The zero crossing is defined as the number of times the signal changes sign.
# For this, you can use the signbit, diff, and nonzero functions from numpy.

# %%
def calculate_zero_crossing(x):
    sign_changes = np.signbit(x)
    sign_diff = np.diff(sign_changes)
    return np.count_nonzero(sign_diff)

# Test
calculate_zero_crossing([1, -1, 2, 3, -2])
# Out:
# 3

# %% [markdown]
# Create a function named **calculate_rms(x)** that returns the Root Mean Square (RMS) of a signal x. We will use the nanmean function instead of the mean function from numpy.

# %%
def calculate_rms(x):
    return np.sqrt(np.nanmean(np.square(x)))

# Test
calculate_rms([2, -2, 2])
# Out:
# 2.0

# %% [markdown]
# Create a function named calculate_entropy(x) that calculates the Shannon entropy of a signal x using the entropy function from scipy.stats.

# %%
from scipy.stats import entropy

def calculate_entropy(x):
    _, counts = np.unique(x, return_counts=True)
    probabilities = counts / counts.sum()
    return entropy(probabilities)

# Test
calculate_entropy([1, 2, 3, 3])
# Out:
# 1.0397207708399179

# %% [markdown]
# Create a function get_features(x) that combines the features calculated by all previous functions including caculate_stats_features.

# %%
def get_features(x):
    max, min, mean, median, var  = calculate_stats_features(x)
    zeros_cross = calculate_zero_crossing(x)
    rms = calculate_rms(x)
    entropy = calculate_entropy(x)
    return {
        "max": max,
        "min": min,
        "mean": mean,
        "median": median,
        "var": var,
        "zeros_cross": zeros_cross,
        "rms": rms,
        "entropy": entropy
    }

# Test
get_features([1, -1, 2, -2, 3, 4])
# Out:
# {'max': 4,
#  'min': -2,
#  'mean': 1.1666666666666667,
#  'median': 1.5,
#  'var': 4.472222222222222,
#  'zeros_cross': 4,
#  'rms': 2.41522945769824,
#  'entropy': 1.791759469228055}

# %% [markdown]
# Load the small ecg dataset
# Use your fonction get_features create a new dataframe where you have all the feature as X and y as the label.
# Train a random forest on it after doing a train test split if the dataset is not too small

# %%
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("ECG-laurent.csv")
labels = df["1"]
data_df = df.drop(columns=["0", "1"])

data_df
# Out:
# /tmp/ipykernel_83158/887217422.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("ECG-laurent.csv")
#             2         3         4         5         6         7         8  \
# 0   -0.060085  0.001638 -0.014941 -0.018776 -0.110048 -0.160348 -0.196445
# 1   -0.467585 -0.650931 -0.595663 -0.627657 -0.552164 -0.532318 -0.500500
# 2   -0.155555 -0.229827 -0.207653 -0.210114 -0.191253 -0.184057 -0.152477
# 3    0.099644  0.098019  0.089555  0.108130  0.070369  0.083866  0.073525
# 4   -0.368856 -0.530640 -0.487672 -0.447722 -0.276366 -0.292531 -0.236326
# ..        ...       ...       ...       ...       ...       ...       ...
# 157  0.074907  0.105856 -0.000567 -0.439990 -0.876207 -1.187291 -1.334461
# 158 -0.320028 -0.404340 -0.396922 -0.409747 -0.408599 -0.397462 -0.391675
# 159 -0.117367 -0.069165 -0.072747 -0.090340 -0.095915 -0.094605 -0.138618
# 160  0.191584  0.405085  0.315481  0.218790 -0.024663 -0.169857 -0.366068
# 161  0.118752  0.392734  0.244206  0.208688  0.097630 -0.171194 -0.322495
#
#             9        10        11  ...     65528     65529     65530  \
# 0   -0.287140 -0.383509 -0.397815  ... -0.145316 -0.088612  0.001568
# 1   -0.486974 -0.480109 -0.429882  ...  0.273010  0.279927  0.213876
# 2   -0.171106 -0.159727 -0.180824  ... -1.238173 -1.112138 -0.812259
# 3    0.061310  0.081658  0.057652  ... -0.291689 -0.111845  0.180895
# 4   -0.209993 -0.174277 -0.187081  ... -0.546984 -0.427314 -0.527221
# ..        ...       ...       ...  ...       ...       ...       ...
# 157 -1.255440 -1.070235 -0.898777  ... -0.027454  0.002023  0.025988
# 158 -0.345731 -0.350851 -0.329378  ... -0.235219 -0.209356 -0.203681
# 159 -0.139901 -0.146395 -0.154829  ... -0.194281 -0.188166 -0.179020
# 160 -0.493332 -0.618309 -0.690620  ... -0.203226 -0.223304 -0.226758
# 161 -0.314085 -0.295623 -0.334766  ... -0.229654 -0.227367 -0.237788
#
#         65531     65532     65533     65534     65535     65536     65537
# 0    0.066026  0.154291  0.214976  0.227396  0.172451  0.011588 -0.154281
# 1    0.137012  0.019218 -0.031818 -0.068809 -0.068333 -0.178109 -0.136239
# 2   -0.595419 -0.444057 -0.326833 -0.117486 -0.038309 -0.015658  0.004507
# 3    0.373213  0.486517  0.394578  0.283331  0.169355  0.166666  0.146715
# 4   -0.588838 -0.624649 -0.577075 -0.652600 -0.500391 -0.386848 -0.161838
# ..        ...       ...       ...       ...       ...       ...       ...
# 157  0.018896  0.033075  0.050003  0.059558  0.056467  0.098536  0.089279
# 158 -0.195236 -0.203310 -0.192466 -0.200470 -0.177530 -0.195617 -0.168229
# 159 -0.201753 -0.184603 -0.185422 -0.180237 -0.187840 -0.172069 -0.171569
# 160 -0.238972 -0.218572 -0.261438 -0.243642 -0.320345 -0.296373 -0.381885
# 161 -0.277769 -0.221940 -0.239414 -0.211494 -0.217100 -0.271023 -0.403293
#
# [162 rows x 65536 columns]

# %%
labels
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 157    2
# 158    2
# 159    2
# 160    2
# 161    2
# Name: 1, Length: 162, dtype: int64

# %%
features_df = data_df.apply(lambda x: pd.Series(get_features(x)), axis=1)
features_df
# Out:
#           max       min      mean    median       var  zeros_cross       rms  \
# 0    3.006143 -2.460911 -0.268554 -0.346791  0.420271       4154.0  0.701707
# 1    2.527708 -3.550697 -0.221014 -0.106818  0.536639       3768.0  0.765171
# 2    2.264555 -3.929179 -0.163022 -0.153941  0.182135       2253.0  0.456849
# 3    3.055421 -1.906982  0.053962  0.051409  0.158568       3102.0  0.401846
# 4    2.035001 -1.575197 -0.148872 -0.174830  0.111417       4748.0  0.365486
# ..        ...       ...       ...       ...       ...          ...       ...
# 157  0.635837 -2.036593 -0.217742 -0.113975  0.165278       2068.0  0.461183
# 158  2.777683 -1.408466 -0.270539 -0.258593  0.023627        692.0  0.311157
# 159  0.919894 -1.070185 -0.172078 -0.164195  0.018569       1762.0  0.219498
# 160  7.078177 -5.961910 -0.343730 -0.390100  0.545255       3645.0  0.814497
# 161  4.478441 -4.748514 -0.264106 -0.214821  0.213515       4237.0  0.532229
#
#        entropy
# 0    11.090355
# 1    11.090355
# 2    11.090355
# 3    11.090355
# 4    11.090355
# ..         ...
# 157  11.090355
# 158  11.090355
# 159  11.090355
# 160  11.090355
# 161  11.090355
#
# [162 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_df, labels, test_size=0.33, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
train_accuracy = rf_model.score(X_train, y_train)
test_accuracy = rf_model.score(X_test, y_test)

print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Train accuracy: 1.0000
# Test accuracy: 0.7963

# %% [markdown]
# try to tweak the model hyperparameter to see if it works
#
# > Here we are going to look for the best hyper-params we can have in 100 trials with Optuna

# %%
def objective_rf(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 32, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 16),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 16)
    }
    model = RandomForestClassifier(**param)
    score = cross_val_score(model, X_train, y_train, cv=2, scoring='accuracy').mean()
    return score

# %%
study_rf = optuna.create_study(direction='maximize')
# %time study_rf.optimize(objective_rf, n_trials=100)
# Out:
# [I 2025-01-09 23:55:38,198] A new study created in memory with name: no-name-b7abd314-5ae2-4c67-8c8c-77a2b46a2fec
# [I 2025-01-09 23:55:38,366] Trial 0 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 60, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.5833333333333333.
# [I 2025-01-09 23:55:39,070] Trial 1 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 237, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:39,860] Trial 2 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 259, 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:40,226] Trial 3 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 144, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 12}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:40,624] Trial 4 finished with value: 0.8148148148148148 and parameters: {'n_estimators': 164, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:40,841] Trial 5 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 83, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 15}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:41,393] Trial 6 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 221, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 9}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:41,597] Trial 7 finished with value: 0.5925925925925926 and parameters: {'n_estimators': 85, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 11}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:41,715] Trial 8 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 43, 'max_depth': 23, 'min_samples_split': 16, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:42,231] Trial 9 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 207, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 12}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:42,990] Trial 10 finished with value: 0.8055555555555556 and parameters: {'n_estimators': 300, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.8240740740740741.
# [I 2025-01-09 23:55:43,090] Trial 11 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 26, 'max_depth': 31, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.8425925925925926.
# [I 2025-01-09 23:55:43,470] Trial 12 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 141, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.8425925925925926.
# [I 2025-01-09 23:55:43,812] Trial 13 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 131, 'max_depth': 31, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:44,100] Trial 14 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 111, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:44,173] Trial 15 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 16, 'max_depth': 31, 'min_samples_split': 8, 'min_samples_leaf': 7}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:44,645] Trial 16 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 180, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:44,706] Trial 17 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 11, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:45,007] Trial 18 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 115, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:45,147] Trial 19 finished with value: 0.8055555555555556 and parameters: {'n_estimators': 48, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 13 with value: 0.8518518518518519.
# [I 2025-01-09 23:55:45,437] Trial 20 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 107, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:45,759] Trial 21 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 119, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:46,012] Trial 22 finished with value: 0.8148148148148148 and parameters: {'n_estimators': 90, 'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:46,471] Trial 23 finished with value: 0.8055555555555556 and parameters: {'n_estimators': 185, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:46,624] Trial 24 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 65, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:46,710] Trial 25 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 33, 'max_depth': 24, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:46,997] Trial 26 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 130, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:47,295] Trial 27 finished with value: 0.712962962962963 and parameters: {'n_estimators': 164, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 9}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:47,483] Trial 28 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 91, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:47,632] Trial 29 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 60, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 16}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:47,858] Trial 30 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 103, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:48,095] Trial 31 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 111, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:48,239] Trial 32 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 66, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:48,499] Trial 33 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 134, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:48,784] Trial 34 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 155, 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:49,128] Trial 35 finished with value: 0.8148148148148148 and parameters: {'n_estimators': 182, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:49,294] Trial 36 finished with value: 0.8148148148148148 and parameters: {'n_estimators': 76, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:49,747] Trial 37 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 252, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:49,936] Trial 38 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 98, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:50,336] Trial 39 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 151, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 10}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:50,446] Trial 40 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 29, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:50,771] Trial 41 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 114, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:51,086] Trial 42 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 120, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:51,449] Trial 43 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 129, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:51,681] Trial 44 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 78, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:52,215] Trial 45 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 210, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 14}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:52,513] Trial 46 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 103, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:52,970] Trial 47 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 167, 'max_depth': 27, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:53,336] Trial 48 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 134, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:53,728] Trial 49 finished with value: 0.8148148148148148 and parameters: {'n_estimators': 146, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:53,909] Trial 50 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 54, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:54,228] Trial 51 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 107, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:54,551] Trial 52 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 114, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:54,880] Trial 53 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 118, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:55,116] Trial 54 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 76, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:55,887] Trial 55 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 297, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:56,148] Trial 56 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 90, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:56,607] Trial 57 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 172, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:56,930] Trial 58 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 123, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:57,444] Trial 59 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 193, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:57,752] Trial 60 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 109, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:58,133] Trial 61 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 142, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:58,587] Trial 62 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 158, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:58,981] Trial 63 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 155, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:59,273] Trial 64 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 141, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:55:59,651] Trial 65 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 135, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:00,046] Trial 66 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 144, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 11}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:00,331] Trial 67 finished with value: 0.75 and parameters: {'n_estimators': 98, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:00,660] Trial 68 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 125, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:00,983] Trial 69 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 113, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:01,348] Trial 70 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 149, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:01,644] Trial 71 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 155, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:01,931] Trial 72 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 159, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:02,334] Trial 73 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 176, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:02,629] Trial 74 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 138, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:02,893] Trial 75 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 128, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:03,241] Trial 76 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 192, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:03,559] Trial 77 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 165, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:03,755] Trial 78 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 99, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:03,949] Trial 79 finished with value: 0.8518518518518519 and parameters: {'n_estimators': 97, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:04,125] Trial 80 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 84, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:04,359] Trial 81 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 120, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:04,574] Trial 82 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 111, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:04,780] Trial 83 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 105, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:04,974] Trial 84 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 91, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:05,203] Trial 85 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 115, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:05,460] Trial 86 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 130, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:05,753] Trial 87 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 158, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:06,136] Trial 88 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 138, 'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:06,290] Trial 89 finished with value: 0.8240740740740741 and parameters: {'n_estimators': 70, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:06,494] Trial 90 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 98, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:06,737] Trial 91 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 125, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:07,021] Trial 92 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 147, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:07,443] Trial 93 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 126, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:07,724] Trial 94 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 115, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:08,222] Trial 95 finished with value: 0.8425925925925926 and parameters: {'n_estimators': 152, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:08,667] Trial 96 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 132, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:08,990] Trial 97 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 92, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:09,527] Trial 98 finished with value: 0.5833333333333333 and parameters: {'n_estimators': 170, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 13}. Best is trial 20 with value: 0.8611111111111112.
# [I 2025-01-09 23:56:10,017] Trial 99 finished with value: 0.8611111111111112 and parameters: {'n_estimators': 142, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.8611111111111112.
# CPU times: user 31.7 s, sys: 90.1 ms, total: 31.8 s
# Wall time: 31.8 s

# %%
print("Best parameters", study_rf.best_params)
print("Best cross validation score", study_rf.best_value)

rf_model = RandomForestClassifier(**study_rf.best_params, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# Best parameters {'n_estimators': 107, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 1}
# Best cross validation score 0.8611111111111112
# RandomForestClassifier(max_depth=24, min_samples_split=5, n_estimators=107,
#                        random_state=42)

# %%
train_accuracy = rf_model.score(X_train, y_train)
test_accuracy = rf_model.score(X_test, y_test)

print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Train accuracy: 0.9907
# Test accuracy: 0.7963

# %% [markdown]
# ## Fourier transform features

# %% [markdown]
# We want now to see if a model using only fourier transform could work.
#
# create a function get_fourier_coefficients(ecg)

# %%
def get_fourier_coefficients(ecg):
    fft_result = np.fft.fft(ecg)
    fft_mag = np.abs(fft_result)
    return fft_mag[:len(fft_mag)//2]

# Test
signal = np.sin([0, 1, 2, 3, 4])
get_fourier_coefficients(signal)
# Out:
# array([1.13508592, 2.13669854])

# %% [markdown]
# Using this function create a dataframe df_fourrier containing the fourrier transform coefficients and the label

# %%
df_fourier = data_df.apply(lambda x: pd.Series(get_fourier_coefficients(x)), axis=1)
df_fourier.columns = df_fourier.columns.astype(str)
df_fourier
# Out:
#                 0            1            2            3            4  \
# 0    17599.976889  1850.171567   295.333800  1185.545859   926.385162
# 1    14484.396444  4137.499334  2152.391165  2520.424900  2066.642615
# 2    10683.818667   400.463461   481.532272   729.461562   964.923609
# 3     3536.462222   313.204866   531.520312   667.082007   647.502832
# 4     9756.496000   303.329945   596.020424   609.179346   380.981983
# ..            ...          ...          ...          ...          ...
# 157  14269.954560   593.412836   760.985169  1294.411838  1341.284484
# 158  17730.076160   378.721372   408.463206   581.751509   276.486875
# 159  11277.319680  1434.196761  2603.621630   769.678837  1109.373133
# 160  22526.704640   289.587563   621.209385   322.026792   332.194610
# 161  17308.451840   683.773983  1434.478998  2887.008289   976.316846
#
#                5            6            7            8            9  ...  \
# 0     538.293366   828.133738   689.752202  1559.152560   545.466498  ...
# 1    1640.749953  1579.574817   945.659290  1648.125085  1195.160663  ...
# 2     946.182174   618.667927  1231.230068    82.521093   910.135298  ...
# 3     600.576281   620.723292   409.162029  2237.361623   501.455323  ...
# 4     272.183845  1134.805832   111.595226   865.347508   194.837216  ...
# ..           ...          ...          ...          ...          ...  ...
# 157   913.092712   421.080003  1230.467798   495.875861   310.455683  ...
# 158   177.656101   818.958481   415.362422   791.562387   313.919207  ...
# 159   479.235405   778.097122  1163.406930   628.928545   715.623275  ...
# 160   843.567029   683.896537   939.492166  1015.935540   648.703645  ...
# 161   847.116245  1962.896372   718.249410   608.238326   585.244309  ...
#
#         32758     32759     32760     32761     32762     32763      32764  \
# 0    1.099556  1.045791  0.235144  1.865392  1.570794  1.264249   1.287078
# 1    1.722051  2.652570  6.639854  0.622695  1.729210  2.705399   0.623744
# 2    8.287070  4.246531  2.753554  6.270798  4.136835  1.777825   1.008231
# 3    4.377541  1.592234  3.068360  1.958553  2.909697  3.388771   3.267543
# 4    7.524246  7.355356  2.491244  8.254273  9.044668  6.631883   5.825186
# ..        ...       ...       ...       ...       ...       ...        ...
# 157  0.897350  1.927539  0.518119  0.248199  2.120751  1.818941   2.064936
# 158  3.115961  3.087415  0.922637  1.543277  3.281298  1.411815   0.522622
# 159  2.787532  0.483426  1.611714  1.507179  0.769242  0.925464   2.203433
# 160  6.233339  7.491898  3.492366  5.710833  7.020063  5.326488  15.122163
# 161  3.842347  6.105749  2.198380  2.000216  5.178174  3.550803   4.436628
#
#         32765     32766      32767
# 0    0.846852  1.615356   0.373965
# 1    0.574554  1.559272   0.884378
# 2    2.256532  3.618107   5.542327
# 3    2.945765  2.518522   2.006570
# 4    6.519294  8.791134  11.619491
# ..        ...       ...        ...
# 157  2.810718  2.494118   2.860149
# 158  1.670959  1.728851   1.948227
# 159  1.064754  1.467670   2.721503
# 160  7.707624  0.629684  11.191931
# 161  1.599120  4.336821   3.751544
#
# [162 rows x 32768 columns]

# %% [markdown]
# Try to train a model using the Fourrier coefficient

# %%
X_train, X_test, y_train, y_test = train_test_split(df_fourier, labels, test_size=0.33, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
train_accuracy = rf_model.score(X_train, y_train)
test_accuracy = rf_model.score(X_test, y_test)

print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Train accuracy: 1.0000
# Test accuracy: 0.6667

# %% [markdown]
# > Here we are again going to look for the best hyper-params we can have in 100 trials with Optuna

# %%
def objective_rf(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 32, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 16),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 16)
    }
    model = RandomForestClassifier(**param)
    score = cross_val_score(model, X_train, y_train, cv=2, scoring='accuracy').mean()
    return score

# %%
study_rf = optuna.create_study(direction='maximize')
# %time study_rf.optimize(objective_rf, n_trials=100)
# Out:
# [I 2025-01-09 23:56:11,857] A new study created in memory with name: no-name-ea9c2cdf-97c9-4eca-98dd-fe29d67f0153
# [I 2025-01-09 23:56:13,532] Trial 0 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 234, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.7037037037037037.
# [I 2025-01-09 23:56:14,449] Trial 1 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 78, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.7037037037037037.
# [I 2025-01-09 23:56:15,436] Trial 2 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 95, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.7037037037037037.
# [I 2025-01-09 23:56:17,000] Trial 3 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 182, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.7037037037037037.
# [I 2025-01-09 23:56:18,611] Trial 4 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 189, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.7037037037037037.
# [I 2025-01-09 23:56:19,595] Trial 5 finished with value: 0.712962962962963 and parameters: {'n_estimators': 85, 'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 5 with value: 0.712962962962963.
# [I 2025-01-09 23:56:21,065] Trial 6 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 184, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 5 with value: 0.712962962962963.
# [I 2025-01-09 23:56:22,132] Trial 7 finished with value: 0.712962962962963 and parameters: {'n_estimators': 145, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 14}. Best is trial 5 with value: 0.712962962962963.
# [I 2025-01-09 23:56:23,108] Trial 8 finished with value: 0.6851851851851851 and parameters: {'n_estimators': 124, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 14}. Best is trial 5 with value: 0.712962962962963.
# [I 2025-01-09 23:56:24,717] Trial 9 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 196, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 5 with value: 0.712962962962963.
# [I 2025-01-09 23:56:25,349] Trial 10 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 15, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:25,977] Trial 11 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 15, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:26,582] Trial 12 finished with value: 0.6574074074074074 and parameters: {'n_estimators': 10, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:27,210] Trial 13 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 15, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:27,955] Trial 14 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 49, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 12}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:29,645] Trial 15 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 269, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 11}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:30,536] Trial 16 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 56, 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7314814814814814.
# [I 2025-01-09 23:56:31,352] Trial 17 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 46, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 5}. Best is trial 17 with value: 0.7314814814814815.
# [I 2025-01-09 23:56:32,142] Trial 18 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 44, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 17 with value: 0.7314814814814815.
# [I 2025-01-09 23:56:33,233] Trial 19 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 115, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 10}. Best is trial 17 with value: 0.7314814814814815.
# [I 2025-01-09 23:56:34,002] Trial 20 finished with value: 0.6574074074074074 and parameters: {'n_estimators': 47, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 16}. Best is trial 17 with value: 0.7314814814814815.
# [I 2025-01-09 23:56:34,439] Trial 21 finished with value: 0.75 and parameters: {'n_estimators': 15, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:35,001] Trial 22 finished with value: 0.75 and parameters: {'n_estimators': 35, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:35,702] Trial 23 finished with value: 0.712962962962963 and parameters: {'n_estimators': 71, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:36,265] Trial 24 finished with value: 0.712962962962963 and parameters: {'n_estimators': 36, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:37,089] Trial 25 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 107, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:37,752] Trial 26 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 65, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:39,760] Trial 27 finished with value: 0.712962962962963 and parameters: {'n_estimators': 300, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:40,283] Trial 28 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 34, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:41,378] Trial 29 finished with value: 0.712962962962963 and parameters: {'n_estimators': 154, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:42,243] Trial 30 finished with value: 0.6851851851851852 and parameters: {'n_estimators': 133, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 9}. Best is trial 21 with value: 0.75.
# [I 2025-01-09 23:56:42,927] Trial 31 finished with value: 0.7592592592592593 and parameters: {'n_estimators': 67, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:43,713] Trial 32 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 89, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:44,360] Trial 33 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 71, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 7}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:44,900] Trial 34 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 31, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:45,774] Trial 35 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 99, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:46,266] Trial 36 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 31, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:46,914] Trial 37 finished with value: 0.75 and parameters: {'n_estimators': 60, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:47,705] Trial 38 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 82, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:48,359] Trial 39 finished with value: 0.712962962962963 and parameters: {'n_estimators': 59, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:48,841] Trial 40 finished with value: 0.75 and parameters: {'n_estimators': 27, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:49,363] Trial 41 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 28, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:49,901] Trial 42 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 25, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:51,437] Trial 43 finished with value: 0.712962962962963 and parameters: {'n_estimators': 218, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:52,127] Trial 44 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 61, 'max_depth': 16, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:52,956] Trial 45 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 83, 'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:53,439] Trial 46 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 12, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:54,275] Trial 47 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 97, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:54,784] Trial 48 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 23, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:55,389] Trial 49 finished with value: 0.712962962962963 and parameters: {'n_estimators': 46, 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 7}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:56,142] Trial 50 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 75, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:56,629] Trial 51 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 24, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:57,177] Trial 52 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 36, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:57,824] Trial 53 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 56, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 31 with value: 0.7592592592592593.
# [I 2025-01-09 23:56:58,321] Trial 54 finished with value: 0.7685185185185185 and parameters: {'n_estimators': 22, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:56:59,704] Trial 55 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 171, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:00,141] Trial 56 finished with value: 0.6851851851851851 and parameters: {'n_estimators': 12, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:00,746] Trial 57 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 42, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:01,256] Trial 58 finished with value: 0.712962962962963 and parameters: {'n_estimators': 20, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:01,942] Trial 59 finished with value: 0.712962962962963 and parameters: {'n_estimators': 53, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:02,626] Trial 60 finished with value: 0.7592592592592593 and parameters: {'n_estimators': 62, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:03,352] Trial 61 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 64, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:03,956] Trial 62 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 41, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:04,379] Trial 63 finished with value: 0.712962962962963 and parameters: {'n_estimators': 10, 'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:05,055] Trial 64 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 53, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:06,066] Trial 65 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 123, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:07,057] Trial 66 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 71, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:07,817] Trial 67 finished with value: 0.6759259259259259 and parameters: {'n_estimators': 37, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:08,715] Trial 68 finished with value: 0.6759259259259259 and parameters: {'n_estimators': 91, 'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 12}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:09,996] Trial 69 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 107, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:10,661] Trial 70 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 20, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:11,339] Trial 71 finished with value: 0.712962962962963 and parameters: {'n_estimators': 27, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:11,901] Trial 72 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 28, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:12,575] Trial 73 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 40, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:13,409] Trial 74 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 49, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:14,431] Trial 75 finished with value: 0.75 and parameters: {'n_estimators': 67, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:15,319] Trial 76 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 69, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 9}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:16,021] Trial 77 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 83, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 14}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:16,684] Trial 78 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 61, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:17,423] Trial 79 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 76, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:17,870] Trial 80 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 19, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 8}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:18,495] Trial 81 finished with value: 0.712962962962963 and parameters: {'n_estimators': 29, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:19,350] Trial 82 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 49, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:21,426] Trial 83 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 254, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:22,180] Trial 84 finished with value: 0.712962962962963 and parameters: {'n_estimators': 33, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:22,823] Trial 85 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 18, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:23,687] Trial 86 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 54, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:24,683] Trial 87 finished with value: 0.712962962962963 and parameters: {'n_estimators': 65, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:25,392] Trial 88 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 43, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:25,949] Trial 89 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 34, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:27,492] Trial 90 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 198, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:28,211] Trial 91 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 58, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:28,983] Trial 92 finished with value: 0.712962962962963 and parameters: {'n_estimators': 77, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:29,620] Trial 93 finished with value: 0.712962962962963 and parameters: {'n_estimators': 50, 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:30,247] Trial 94 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 42, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:30,708] Trial 95 finished with value: 0.6851851851851851 and parameters: {'n_estimators': 16, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:31,191] Trial 96 finished with value: 0.712962962962963 and parameters: {'n_estimators': 24, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:31,993] Trial 97 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 67, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:32,772] Trial 98 finished with value: 0.712962962962963 and parameters: {'n_estimators': 57, 'max_depth': 24, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 54 with value: 0.7685185185185185.
# [I 2025-01-09 23:57:33,671] Trial 99 finished with value: 0.75 and parameters: {'n_estimators': 104, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 54 with value: 0.7685185185185185.
# CPU times: user 1min 21s, sys: 76 ms, total: 1min 21s
# Wall time: 1min 21s

# %%
print("Best parameters", study_rf.best_params)
print("Best cross validation score", study_rf.best_value)

rf_model = RandomForestClassifier(**study_rf.best_params, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# Best parameters {'n_estimators': 22, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3}
# Best cross validation score 0.7685185185185185
# RandomForestClassifier(max_depth=13, min_samples_leaf=3, min_samples_split=11,
#                        n_estimators=22, random_state=42)

# %%
train_accuracy = rf_model.score(X_train, y_train)
test_accuracy = rf_model.score(X_test, y_test)

print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Train accuracy: 0.9722
# Test accuracy: 0.7037

# %% [markdown]
# > Performance is not as good as the previous model

# %% [markdown]
# Try to learn a model using both fourrier coefficient and the features from the previous sections. Does it work ?
#
# > Yes it does:

# %%
X_combined = pd.concat([features_df, df_fourier], axis=1)
X_combined
# Out:
#           max       min      mean    median       var  zeros_cross       rms  \
# 0    3.006143 -2.460911 -0.268554 -0.346791  0.420271       4154.0  0.701707
# 1    2.527708 -3.550697 -0.221014 -0.106818  0.536639       3768.0  0.765171
# 2    2.264555 -3.929179 -0.163022 -0.153941  0.182135       2253.0  0.456849
# 3    3.055421 -1.906982  0.053962  0.051409  0.158568       3102.0  0.401846
# 4    2.035001 -1.575197 -0.148872 -0.174830  0.111417       4748.0  0.365486
# ..        ...       ...       ...       ...       ...          ...       ...
# 157  0.635837 -2.036593 -0.217742 -0.113975  0.165278       2068.0  0.461183
# 158  2.777683 -1.408466 -0.270539 -0.258593  0.023627        692.0  0.311157
# 159  0.919894 -1.070185 -0.172078 -0.164195  0.018569       1762.0  0.219498
# 160  7.078177 -5.961910 -0.343730 -0.390100  0.545255       3645.0  0.814497
# 161  4.478441 -4.748514 -0.264106 -0.214821  0.213515       4237.0  0.532229
#
#        entropy             0            1  ...     32758     32759     32760  \
# 0    11.090355  17599.976889  1850.171567  ...  1.099556  1.045791  0.235144
# 1    11.090355  14484.396444  4137.499334  ...  1.722051  2.652570  6.639854
# 2    11.090355  10683.818667   400.463461  ...  8.287070  4.246531  2.753554
# 3    11.090355   3536.462222   313.204866  ...  4.377541  1.592234  3.068360
# 4    11.090355   9756.496000   303.329945  ...  7.524246  7.355356  2.491244
# ..         ...           ...          ...  ...       ...       ...       ...
# 157  11.090355  14269.954560   593.412836  ...  0.897350  1.927539  0.518119
# 158  11.090355  17730.076160   378.721372  ...  3.115961  3.087415  0.922637
# 159  11.090355  11277.319680  1434.196761  ...  2.787532  0.483426  1.611714
# 160  11.090355  22526.704640   289.587563  ...  6.233339  7.491898  3.492366
# 161  11.090355  17308.451840   683.773983  ...  3.842347  6.105749  2.198380
#
#         32761     32762     32763      32764     32765     32766      32767
# 0    1.865392  1.570794  1.264249   1.287078  0.846852  1.615356   0.373965
# 1    0.622695  1.729210  2.705399   0.623744  0.574554  1.559272   0.884378
# 2    6.270798  4.136835  1.777825   1.008231  2.256532  3.618107   5.542327
# 3    1.958553  2.909697  3.388771   3.267543  2.945765  2.518522   2.006570
# 4    8.254273  9.044668  6.631883   5.825186  6.519294  8.791134  11.619491
# ..        ...       ...       ...        ...       ...       ...        ...
# 157  0.248199  2.120751  1.818941   2.064936  2.810718  2.494118   2.860149
# 158  1.543277  3.281298  1.411815   0.522622  1.670959  1.728851   1.948227
# 159  1.507179  0.769242  0.925464   2.203433  1.064754  1.467670   2.721503
# 160  5.710833  7.020063  5.326488  15.122163  7.707624  0.629684  11.191931
# 161  2.000216  5.178174  3.550803   4.436628  1.599120  4.336821   3.751544
#
# [162 rows x 32776 columns]

# %%
X_train_combined, X_test_combined, y_train_combined, y_test_combined = train_test_split(X_combined, labels, test_size=0.33, random_state=42)

rf_model_combined = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_combined.fit(X_train_combined, y_train_combined)
# Out:
# RandomForestClassifier(random_state=42)

# %%
train_accuracy = rf_model_combined.score(X_train_combined, y_train_combined)
test_accuracy = rf_model_combined.score(X_test_combined, y_test_combined)

print("Combined features")
print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Combined features
# Train accuracy: 1.0000
# Test accuracy: 0.7222

# %% [markdown]
# > Once again, let's try with Optuna

# %%
def objective_rf(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 32, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 16),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 16)
    }
    model = RandomForestClassifier(**param)
    score = cross_val_score(model, X_train_combined, y_train_combined, cv=2, scoring='accuracy').mean()
    return score

# %%
study_rf = optuna.create_study(direction='maximize')
# %time study_rf.optimize(objective_rf, n_trials=100)
# Out:
# [I 2025-01-09 23:57:35,438] A new study created in memory with name: no-name-6a4e154d-8a15-4e5b-983a-19bbd1c2426d
# [I 2025-01-09 23:57:36,071] Trial 0 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 60, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.7222222222222222.
# [I 2025-01-09 23:57:37,368] Trial 1 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 252, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.7222222222222222.
# [I 2025-01-09 23:57:38,915] Trial 2 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.7407407407407407.
# [I 2025-01-09 23:57:40,341] Trial 3 finished with value: 0.75 and parameters: {'n_estimators': 202, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:40,775] Trial 4 finished with value: 0.712962962962963 and parameters: {'n_estimators': 18, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:41,862] Trial 5 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 232, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:42,979] Trial 6 finished with value: 0.712962962962963 and parameters: {'n_estimators': 295, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 14}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:43,499] Trial 7 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 42, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:44,969] Trial 8 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 222, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:45,666] Trial 9 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 109, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 11}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:46,637] Trial 10 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 162, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:47,774] Trial 11 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 181, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:49,421] Trial 12 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:50,224] Trial 13 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 113, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:51,474] Trial 14 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 201, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:52,911] Trial 15 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 264, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:54,124] Trial 16 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 125, 'max_depth': 3, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:55,890] Trial 17 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 207, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:57,324] Trial 18 finished with value: 0.6851851851851851 and parameters: {'n_estimators': 257, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 15}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:57:58,690] Trial 19 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 155, 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:00,290] Trial 20 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 298, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:00,909] Trial 21 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 57, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:01,582] Trial 22 finished with value: 0.712962962962963 and parameters: {'n_estimators': 76, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:02,036] Trial 23 finished with value: 0.6851851851851852 and parameters: {'n_estimators': 20, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:03,000] Trial 24 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 149, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:03,749] Trial 25 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 86, 'max_depth': 17, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:04,911] Trial 26 finished with value: 0.75 and parameters: {'n_estimators': 183, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:06,074] Trial 27 finished with value: 0.712962962962963 and parameters: {'n_estimators': 188, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:07,400] Trial 28 finished with value: 0.712962962962963 and parameters: {'n_estimators': 230, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:08,215] Trial 29 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 136, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:09,086] Trial 30 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 171, 'max_depth': 21, 'min_samples_split': 3, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:09,659] Trial 31 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 46, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:11,166] Trial 32 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 275, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:12,700] Trial 33 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 202, 'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:14,094] Trial 34 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 247, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:14,979] Trial 35 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 89, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:16,400] Trial 36 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 242, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:17,625] Trial 37 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 215, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:18,460] Trial 38 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 185, 'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 13}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:19,386] Trial 39 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 138, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:19,822] Trial 40 finished with value: 0.712962962962963 and parameters: {'n_estimators': 12, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:21,342] Trial 41 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 228, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:22,750] Trial 42 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 218, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:23,878] Trial 43 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 168, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:25,465] Trial 44 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 283, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:26,992] Trial 45 finished with value: 0.712962962962963 and parameters: {'n_estimators': 270, 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:28,109] Trial 46 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 189, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:28,727] Trial 47 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 109, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 16}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:29,751] Trial 48 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 172, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:31,108] Trial 49 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 215, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:32,543] Trial 50 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 238, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:33,853] Trial 51 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 201, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:35,320] Trial 52 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 257, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:36,595] Trial 53 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 206, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:37,596] Trial 54 finished with value: 0.712962962962963 and parameters: {'n_estimators': 153, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:38,811] Trial 55 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 195, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:39,399] Trial 56 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 36, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:41,169] Trial 57 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 179, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:43,183] Trial 58 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 223, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:44,403] Trial 59 finished with value: 0.712962962962963 and parameters: {'n_estimators': 132, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:45,760] Trial 60 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 162, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:46,917] Trial 61 finished with value: 0.712962962962963 and parameters: {'n_estimators': 176, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 12}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:47,887] Trial 62 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 210, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 11}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:48,886] Trial 63 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 162, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:50,200] Trial 64 finished with value: 0.6944444444444444 and parameters: {'n_estimators': 195, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:51,677] Trial 65 finished with value: 0.6851851851851852 and parameters: {'n_estimators': 237, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:52,830] Trial 66 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 147, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:54,096] Trial 67 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 192, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 11}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:56,058] Trial 68 finished with value: 0.712962962962963 and parameters: {'n_estimators': 252, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:57,794] Trial 69 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 290, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:58,639] Trial 70 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 125, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:58:59,974] Trial 71 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 243, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:01,245] Trial 72 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 224, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:02,451] Trial 73 finished with value: 0.75 and parameters: {'n_estimators': 211, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:03,629] Trial 74 finished with value: 0.712962962962963 and parameters: {'n_estimators': 206, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:04,628] Trial 75 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 168, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:05,750] Trial 76 finished with value: 0.712962962962963 and parameters: {'n_estimators': 186, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:06,893] Trial 77 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 178, 'max_depth': 27, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:07,699] Trial 78 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 103, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:09,134] Trial 79 finished with value: 0.712962962962963 and parameters: {'n_estimators': 198, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:10,473] Trial 80 finished with value: 0.712962962962963 and parameters: {'n_estimators': 143, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:12,179] Trial 81 finished with value: 0.712962962962963 and parameters: {'n_estimators': 213, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:14,103] Trial 82 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 263, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:15,883] Trial 83 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 231, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:17,398] Trial 84 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 222, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:18,963] Trial 85 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 276, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:20,456] Trial 86 finished with value: 0.75 and parameters: {'n_estimators': 238, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:21,172] Trial 87 finished with value: 0.75 and parameters: {'n_estimators': 71, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:22,081] Trial 88 finished with value: 0.712962962962963 and parameters: {'n_estimators': 55, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:23,832] Trial 89 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 297, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:24,369] Trial 90 finished with value: 0.7222222222222223 and parameters: {'n_estimators': 32, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:25,092] Trial 91 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 75, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:25,585] Trial 92 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 26, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:26,161] Trial 93 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 44, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:27,430] Trial 94 finished with value: 0.712962962962963 and parameters: {'n_estimators': 203, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:28,663] Trial 95 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 183, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:30,080] Trial 96 finished with value: 0.7407407407407407 and parameters: {'n_estimators': 218, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:31,132] Trial 97 finished with value: 0.7314814814814814 and parameters: {'n_estimators': 208, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:31,815] Trial 98 finished with value: 0.7222222222222222 and parameters: {'n_estimators': 69, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.75.
# [I 2025-01-09 23:59:32,505] Trial 99 finished with value: 0.7314814814814815 and parameters: {'n_estimators': 11, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.75.
# CPU times: user 1min 56s, sys: 129 ms, total: 1min 57s
# Wall time: 1min 57s

# %%
print("Best parameters", study_rf.best_params)
print("Best cross validation score", study_rf.best_value)

rf_model_combined = RandomForestClassifier(**study_rf.best_params, random_state=42)
rf_model_combined.fit(X_train_combined, y_train_combined)
# Out:
# Best parameters {'n_estimators': 202, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Best cross validation score 0.75
# RandomForestClassifier(max_depth=13, n_estimators=202, random_state=42)

# %%
train_accuracy = rf_model_combined.score(X_train_combined, y_train_combined)
test_accuracy = rf_model_combined.score(X_test_combined, y_test_combined)

print("Combined features")
print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Combined features
# Train accuracy: 1.0000
# Test accuracy: 0.7222

# %% [markdown]
# ## Wavelets

# %% [markdown]
# We now wants to use another signal decomposition which are called wavelet. Wavelet are a multi-scale function decomposition on a familly of functions generated from what is called a mother wavelet.
#
# Using PyWavelet make a function get_wavelet_coefficients(ecg) that returns the wavelet coefficient of a given ECG

# %%
import pywt

# %%
def get_wavelet_coefficients(ecg):
    coeffs = pywt.wavedec(ecg, 'db4', level=5)
    return np.concatenate(coeffs)

# %% [markdown]
# Using the get_wavelet_coefficients, create a dataframe when the features are the coefficients and include the label

# %%
df_wavelet = data_df.apply(lambda x: pd.Series(get_wavelet_coefficients(x)), axis=1)
df_wavelet
# Out:
#         0         1         2         3         4         5         6      \
# 0   -0.372010 -0.260654 -0.309907 -0.310574 -0.227890 -0.617469 -3.022413
# 1   -3.173087 -3.259975 -3.247555 -3.213314 -3.233537 -3.503101 -4.413756
# 2   -1.103193 -1.099563 -1.176437 -1.046143 -1.338005 -0.429386 -1.266284
# 3    0.511032  0.524136  0.504724  0.564642  0.127159  1.881995  0.826970
# 4   -2.293174 -2.361759 -2.336108 -2.245817 -2.792341 -0.828481 -0.887523
# ..        ...       ...       ...       ...       ...       ...       ...
# 157 -1.764804 -1.535687 -1.778825 -1.645993 -1.611996 -1.857146  1.004171
# 158 -2.185889 -2.190012 -2.194289 -2.174928 -2.237561 -2.024021 -1.796112
# 159 -0.521020 -0.509723 -0.513106 -0.528018 -0.452068 -0.734531 -0.762689
# 160  0.986213  1.105993  1.075146  0.902425  1.645518 -0.946296 -3.063014
# 161  0.999817  1.045729  0.997724  0.869715  1.761351 -1.514074 -1.972886
#
#         7         8         9      ...     65558     65559     65560  \
# 0   -0.604378 -2.923294 -2.514842  ...  0.009048  0.020990 -0.037387
# 1   -3.744945 -4.174972 -2.149941  ... -0.023929  0.016427  0.000257
# 2    0.946764 -1.024068 -4.975642  ... -0.049528 -0.109406  0.154508
# 3    2.716503  2.056567 -4.306749  ... -0.005747  0.037289  0.045591
# 4   -1.091186 -0.018249 -0.362236  ... -0.025584  0.263982 -0.425948
# ..        ...       ...       ...  ...       ...       ...       ...
# 157 -1.839111  1.440295 -1.415886  ...  0.005358  0.007585 -0.010335
# 158 -1.963102 -1.763992 -1.606030  ... -0.032759  0.007847 -0.012782
# 159 -1.440162 -1.011210 -0.871353  ...  0.014679  0.000326  0.000340
# 160 -0.887315 -3.911404 -2.743744  ... -0.002632  0.016191  0.002240
# 161  0.077463 -2.519855  0.152140  ...  0.008617  0.000801  0.009888
#
#         65561     65562     65563     65564     65565     65566     65567
# 0    0.028253  0.002237 -0.000266 -0.028554  0.014615  0.031316 -0.027797
# 1   -0.018340 -0.019976  0.006214 -0.063029  0.020517  0.055184 -0.012997
# 2    0.025962 -0.032860  0.056736 -0.031413  0.009088  0.012298 -0.058915
# 3    0.031034  0.009156 -0.016872  0.045184 -0.008458 -0.029453  0.015599
# 4    0.128538 -0.049629 -0.076230 -0.007552 -0.001764  0.022396  0.089177
# ..        ...       ...       ...       ...       ...       ...       ...
# 157  0.009463  0.001435  0.001654  0.022055 -0.007558 -0.020769  0.006174
# 158 -0.000983 -0.008603 -0.008715 -0.017159  0.005511  0.017860  0.006525
# 159  0.011216  0.009061  0.001568  0.008229 -0.002588 -0.008707 -0.001065
# 160  0.005429  0.021204  0.028493  0.039656 -0.012011 -0.042655 -0.025372
# 161  0.001010  0.038516  0.006706  0.002083 -0.000744  0.001390 -0.027506
#
# [162 rows x 65568 columns]

# %% [markdown]
# Train a random forest classifier with such features. Does the model work

# %%
X_train_wavelet, X_test_wavelet, y_train_wavelet, y_test_wavelet = train_test_split(df_wavelet, labels, test_size=0.2, random_state=42)

# %% [markdown]
# Add one or several of the previous feature functions and try to train another model

# %%
rf_model_wavelet = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_wavelet.fit(X_train_wavelet, y_train_wavelet)
# Out:
# RandomForestClassifier(random_state=42)

# %%
train_accuracy = rf_model_wavelet.score(X_train_wavelet, y_train_wavelet)
test_accuracy = rf_model_wavelet.score(X_test_wavelet, y_test_wavelet)

print("Wavelet features")
print(f"Train accuracy: {train_accuracy:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Wavelet features
# Train accuracy: 1.0000
# Test accuracy: 0.5758

# %% [markdown]
# > Let's use Optuna as always

# %%
def objective_rf(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 32, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 16),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 16)
    }
    model = RandomForestClassifier(**param)
    score = cross_val_score(model, X_train_wavelet, y_train_wavelet, cv=2, scoring='accuracy').mean()
    return score

# %%
study_rf = optuna.create_study(direction='maximize')
# %time study_rf.optimize(objective_rf, n_trials=100)

# %%
print("Best parameters", study_rf.best_params)
print("Best cross validation score", study_rf.best_value)

rf_model_wavelet = RandomForestClassifier(**study_rf.best_params, random_state=42)
rf_model_wavelet.fit(X_train, y_train)
# Out:
# Best parameters {'n_estimators': 202, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Best cross validation score 0.75
# RandomForestClassifier(max_depth=13, n_estimators=202, random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix

rf_pred = rf_model_wavelet.predict(X_test)
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67        11
#            1       0.71      0.88      0.78        33
#            2       0.67      0.20      0.31        10
#
#     accuracy                           0.70        54
#    macro avg       0.69      0.57      0.59        54
# weighted avg       0.70      0.70      0.67        54

# %% [markdown]
# Specify the methodology you used to train the model and report the various attempts results into a table
#
# > I used Optuna to find the best params
#
# > Here is the requested table:
#
#
# | Feature set | Training accuracy | Test accuracy |Accuracy gap |
# |-------------|------------------|---------------|--------------|
# | Basic features | 0.9907 | 0.7963 | 0.1944 |
# | Fourier features | 0.9722 | 0.7037 | 0.2685 |
# | Combined features | 1.0000 | 0.7222 | 0.2778 |
# | Wavelet features | 1.0000 | 0.5758 | 0.4242 |

# %% [markdown]
# ## Deep learning (1D CNN)

# %% [markdown]
# Now we want to see if we can skip all theses feature engineering techniques !
# Design and train a multi-layer one dimensional CNN using the raw ECG signal as features.
#
#
# Could you reach or surpass the feature based models ?

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### Dataset creation

# %%
class ECGDataset(Dataset):
    def __init__(self, signals, labels):
        self.signals = torch.FloatTensor(signals)
        self.labels = torch.LongTensor(labels)

    def __len__(self):
        return len(self.signals)

    def __getitem__(self, idx):
        return self.signals[idx], self.labels[idx]

# %% [markdown]
# ### Classifier DL model creation

# %%
class ECGClassifier(nn.Module):
    def __init__(self, input_channels=1, num_classes=6):
        super(ECGClassifier, self).__init__()

        self.conv_blocks = nn.Sequential(
            nn.Conv1d(input_channels, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.classifier = nn.Sequential(
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.conv_blocks(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %% [markdown]
# ### Training and eval loops

# %%
def train_model(model, train_loader, criterion, optimizer, device, num_epochs=50):
    model.train()
    train_losses = []
    train_accs = []

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_losses.append(running_loss / len(train_loader))
        train_accs.append(correct / total)

        if (epoch + 1) % 5 == 0:
            print(f'Epoch {epoch+1}/{num_epochs}, train_loss: {train_losses[-1]:.4f}, train_accuracy: {train_accs[-1]:.4f}%')

    return train_losses, train_accs

# %%
def evaluate_model(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return np.array(all_preds), np.array(all_labels)

# %% [markdown]
# ### Splits and dataset pre-processing

# %%
X_cnn = data_df.values.reshape(data_df.values.shape[0], 1, data_df.values.shape[1])
y_cnn = np.array(labels)

X_train_cnn, X_test_cnn, y_train_cnn, y_test_cnn = train_test_split(X_cnn, y_cnn, test_size=0.2, random_state=42, stratify=y_cnn)

# %%
train_dataset = ECGDataset(X_train_cnn, y_train_cnn)
test_dataset = ECGDataset(X_test_cnn, y_test_cnn)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ### Model preparation and training

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_classes = len(np.unique(y_cnn))
model = ECGClassifier(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses, train_accs = train_model( model, train_loader, criterion, optimizer, device, num_epochs=50)
cnn_pred, cnn_true = evaluate_model(model, test_loader, device)
# Out:
# Epoch 5/50, train_loss: 0.6107, train_accuracy: 0.5969%
# Epoch 10/50, train_loss: 0.4964, train_accuracy: 0.7597%
# Epoch 15/50, train_loss: 0.4024, train_accuracy: 0.8682%
# Epoch 20/50, train_loss: 0.3412, train_accuracy: 0.8372%
# Epoch 25/50, train_loss: 0.8200, train_accuracy: 0.8915%
# Epoch 30/50, train_loss: 0.3542, train_accuracy: 0.8682%
# Epoch 35/50, train_loss: 0.2378, train_accuracy: 0.9302%
# Epoch 40/50, train_loss: 0.3905, train_accuracy: 0.8682%
# Epoch 45/50, train_loss: 0.3197, train_accuracy: 0.8450%
# Epoch 50/50, train_loss: 0.6063, train_accuracy: 0.8760%

# %%
print(classification_report(cnn_true, cnn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.86      0.95      0.90        20
#            2       0.83      0.83      0.83         6
#
#     accuracy                           0.88        33
#    macro avg       0.90      0.83      0.86        33
# weighted avg       0.89      0.88      0.88        33

# %% [markdown]
# > The final accuracy on the test dataset is much higher than what I've done with the RandomForest models

# %%
plt.figure(figsize=(12, 4))

# 1
plt.subplot(1, 2, 1)
plt.plot(train_losses)
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# 2
plt.subplot(1, 2, 2)
plt.plot(train_accs)
plt.title('Training accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()
