# %% [markdown]
# # Federated learning local
#
# **Prénom**: Alexandre \
# **Nom**: Devaux Riviere \
# **Login**: alexandre.devaux-riviere

# %%
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset
from typing import List, Dict, Tuple, Callable

import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Load the MNIST dataset (or any other dataset like HAM 10000)

# %%
def get_mnist_data():
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    train_dataset = torchvision.datasets.MNIST(
        root='./data',
        train=True,
        transform=transform,
        download=True,
    )

    test_dataset = torchvision.datasets.MNIST(
        root='./data',
        train=False,
        transform=transform,
        download=True,
    )

    return train_dataset, test_dataset

# %% [markdown]
# ### 2. Extract two subsets of 600 data points each (without intersection)

# %%
def create_subsets(train_dataset, test_dataset, subset_size) -> List[Subset]:
    """Create non-overlapping subsets of the dataset (= 2 parts)"""
    indices = np.random.permutation(len(train_dataset))
    subset1 = Subset(train_dataset, indices[:subset_size])
    subset2 = Subset(train_dataset, indices[subset_size:subset_size*2])

    # 50 examples per local batch (written in the paper)
    train_loader_1 = DataLoader(subset1, batch_size=50, shuffle=True)
    train_loader_2 = DataLoader(subset2, batch_size=50, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)

    return train_loader_1, train_loader_2, test_loader

# %% [markdown]
# ### 3. Create a simple Convolutional Neural Network (2 convolutional layers and 2 dense layers, for example)

# %%
num_classes = 10

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=5)
        self.pool = nn.MaxPool2d(2)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(64 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 4 * 4)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### 4. Create a function average_model_parameters(models: iterable, average_weight): iterable that takes a list of models as an argument and returns the weighted average of the parameters of each model.

# %%
def average_model_parameters(models: List[nn.Module], average_weight: List[float]):
    """Compute weighted average of model parameters"""
    averaged_params = {}

    for key in models[0].state_dict().keys():
        acc = [weight * model.state_dict()[key] for model, weight in zip(models, average_weight)]
        averaged_params[key] = sum(acc)

    return averaged_params

# %% [markdown]
# ### 5. Create a function that updates the parameters of a model from a list of values

# %%
def update_model_parameters(model: nn.Module, parameters: Dict[str, torch.Tensor]):
    """Update model parameters with given values"""
    model.load_state_dict(parameters)

# %% [markdown]
# ### 6. Create a script/code/function that reproduces Algorithm 1, considering that both models are on your machine. Use an average_weight=[1/2, 1/2]. Reuse the same setup as in the article (50 examples per local batch)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Training loop

# %%
def train_model(
    model: nn.Module, train_loader: DataLoader,
    epochs: int, device: str
) -> float:
    """Train model and returns accuracy and loss"""
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    model.train()

    for _ in range(epochs):
        for _, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

    return loss.item()

# %% [markdown]
# ### Evaluation loop

# %%
def evaluate_model(model: nn.Module, test_loader: DataLoader, device: str) -> Tuple[float, float]:
    """Evaluate model accuracy and loss"""
    model.eval()
    test_loss = 0
    correct = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)
            test_loss += criterion(output, target).item()

            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    return test_loss / len(test_loader), correct / len(test_loader.dataset)

# %% [markdown]
# ### Main federated averaging algorithm

# %%
def federated_averaging(
    average_weight: list = [0.5, 0.5], subset_size: int = 600,
    num_rounds: int = 10, local_epochs: int = 5,
    shared_init: bool = True, device: str = device
):
    """Run federated learning experiment"""
    print(f"==> device used {device}")

    train_dataset, test_dataset = get_mnist_data()
    train_loader_1, train_loader_2, test_loader = create_subsets(train_dataset, test_dataset, subset_size)

    # Models init
    models = [SimpleCNN().to(device), SimpleCNN().to(device)]
    training_loaders = [train_loader_1, train_loader_2]

    if shared_init:
        # same initialization for all models
        shared_params = models[0].state_dict()
        models[1].load_state_dict(shared_params)


    history = {'accuracy': [], 'loss': []}

    for round_num in range(num_rounds):
        model_id = 1
        for model, t_loader in zip(models, training_loaders):
            loss = train_model(model, t_loader, local_epochs, device)
            test_loss, t_accuracy = evaluate_model(model, test_loader, device)
            print(f"Training model {model_id} | train_loss: {loss:.3f}, test_loss: {test_loss:.3f}, test_accuracy: {t_accuracy:.3f}, ")
            model_id += 1

        # Average model parameters
        averaged_params = average_model_parameters(models, average_weight)

        # Update models with averaged parameters
        for model in models:
            update_model_parameters(model, averaged_params)

        # Evaluate global model
        test_loss, accuracy = evaluate_model(models[0], test_loader, device)
        history['loss'].append(test_loss)
        history['accuracy'].append(accuracy)

        print(f"-- Round {round_num + 1} Federated Model --\n==> test_loss = {test_loss:.3f}, test_accuracy = {accuracy:.3f}\n")

    return history

# %% [markdown]
# ### 7. Train your models without initializing the common parameters and measure the performance on the entire dataset.

# %%
history_no_init = federated_averaging(
    average_weight = [0.5, 0.5],
    num_rounds = 10,
    local_epochs = 5,
    shared_init = False
)
# Out:
# ==> device used cuda
# Training model 1 | train_loss: 2.222, test_loss: 2.215, test_accuracy: 0.373,
# Training model 2 | train_loss: 2.212, test_loss: 2.198, test_accuracy: 0.486,
# -- Round 1 Federated Model --
# ==> test_loss = 2.297, test_accuracy = 0.157
#
# Training model 1 | train_loss: 2.289, test_loss: 2.281, test_accuracy: 0.196,
# Training model 2 | train_loss: 2.279, test_loss: 2.280, test_accuracy: 0.245,
# -- Round 2 Federated Model --
# ==> test_loss = 2.280, test_accuracy = 0.176
#
# Training model 1 | train_loss: 2.243, test_loss: 2.256, test_accuracy: 0.210,
# Training model 2 | train_loss: 2.280, test_loss: 2.255, test_accuracy: 0.281,
# -- Round 3 Federated Model --
# ==> test_loss = 2.255, test_accuracy = 0.225
#
# Training model 1 | train_loss: 2.213, test_loss: 2.211, test_accuracy: 0.340,
# Training model 2 | train_loss: 2.210, test_loss: 2.210, test_accuracy: 0.421,
# -- Round 4 Federated Model --
# ==> test_loss = 2.209, test_accuracy = 0.351
#
# Training model 1 | train_loss: 2.107, test_loss: 2.106, test_accuracy: 0.562,
# Training model 2 | train_loss: 2.096, test_loss: 2.105, test_accuracy: 0.545,
# -- Round 5 Federated Model --
# ==> test_loss = 2.103, test_accuracy = 0.552
#
# Training model 1 | train_loss: 1.908, test_loss: 1.814, test_accuracy: 0.684,
# Training model 2 | train_loss: 1.866, test_loss: 1.810, test_accuracy: 0.686,
# -- Round 6 Federated Model --
# ==> test_loss = 1.809, test_accuracy = 0.721
#
# Training model 1 | train_loss: 1.261, test_loss: 1.176, test_accuracy: 0.784,
# Training model 2 | train_loss: 1.165, test_loss: 1.171, test_accuracy: 0.796,
# -- Round 7 Federated Model --
# ==> test_loss = 1.170, test_accuracy = 0.802
#
# Training model 1 | train_loss: 0.712, test_loss: 0.723, test_accuracy: 0.831,
# Training model 2 | train_loss: 0.796, test_loss: 0.706, test_accuracy: 0.834,
# -- Round 8 Federated Model --
# ==> test_loss = 0.704, test_accuracy = 0.844
#
# Training model 1 | train_loss: 0.686, test_loss: 0.552, test_accuracy: 0.854,
# Training model 2 | train_loss: 0.533, test_loss: 0.530, test_accuracy: 0.853,
# -- Round 9 Federated Model --
# ==> test_loss = 0.526, test_accuracy = 0.863
#
# Training model 1 | train_loss: 0.319, test_loss: 0.450, test_accuracy: 0.874,
# Training model 2 | train_loss: 0.468, test_loss: 0.435, test_accuracy: 0.881,
# -- Round 10 Federated Model --
# ==> test_loss = 0.437, test_accuracy = 0.880

# %% [markdown]
# ### 8. Train your models with the initialization of common parameters and verify that the performance is better.

# %%
history_init = federated_averaging(
    average_weight = [0.5, 0.5],
    num_rounds = 10,
    local_epochs = 5,
    shared_init = True
)
# Out:
# ==> device used cuda
# Training model 1 | train_loss: 2.238, test_loss: 2.228, test_accuracy: 0.383,
# Training model 2 | train_loss: 2.264, test_loss: 2.229, test_accuracy: 0.320,
# -- Round 1 Federated Model --
# ==> test_loss = 2.228, test_accuracy = 0.355
#
# Training model 1 | train_loss: 2.050, test_loss: 2.052, test_accuracy: 0.534,
# Training model 2 | train_loss: 2.068, test_loss: 2.053, test_accuracy: 0.497,
# -- Round 2 Federated Model --
# ==> test_loss = 2.049, test_accuracy = 0.556
#
# Training model 1 | train_loss: 1.586, test_loss: 1.537, test_accuracy: 0.710,
# Training model 2 | train_loss: 1.438, test_loss: 1.531, test_accuracy: 0.723,
# -- Round 3 Federated Model --
# ==> test_loss = 1.529, test_accuracy = 0.729
#
# Training model 1 | train_loss: 0.953, test_loss: 0.858, test_accuracy: 0.820,
# Training model 2 | train_loss: 0.912, test_loss: 0.865, test_accuracy: 0.817,
# -- Round 4 Federated Model --
# ==> test_loss = 0.854, test_accuracy = 0.827
#
# Training model 1 | train_loss: 0.616, test_loss: 0.566, test_accuracy: 0.851,
# Training model 2 | train_loss: 0.575, test_loss: 0.552, test_accuracy: 0.862,
# -- Round 5 Federated Model --
# ==> test_loss = 0.552, test_accuracy = 0.861
#
# Training model 1 | train_loss: 0.518, test_loss: 0.456, test_accuracy: 0.864,
# Training model 2 | train_loss: 0.320, test_loss: 0.456, test_accuracy: 0.870,
# -- Round 6 Federated Model --
# ==> test_loss = 0.434, test_accuracy = 0.882
#
# Training model 1 | train_loss: 0.238, test_loss: 0.371, test_accuracy: 0.894,
# Training model 2 | train_loss: 0.384, test_loss: 0.385, test_accuracy: 0.887,
# -- Round 7 Federated Model --
# ==> test_loss = 0.367, test_accuracy = 0.895
#
# Training model 1 | train_loss: 0.203, test_loss: 0.346, test_accuracy: 0.897,
# Training model 2 | train_loss: 0.310, test_loss: 0.338, test_accuracy: 0.906,
# -- Round 8 Federated Model --
# ==> test_loss = 0.328, test_accuracy = 0.905
#
# Training model 1 | train_loss: 0.185, test_loss: 0.302, test_accuracy: 0.912,
# Training model 2 | train_loss: 0.325, test_loss: 0.324, test_accuracy: 0.901,
# -- Round 9 Federated Model --
# ==> test_loss = 0.306, test_accuracy = 0.909
#
# Training model 1 | train_loss: 0.195, test_loss: 0.287, test_accuracy: 0.917,
# Training model 2 | train_loss: 0.158, test_loss: 0.299, test_accuracy: 0.911,
# -- Round 10 Federated Model --
# ==> test_loss = 0.282, test_accuracy = 0.919

# %%
def display_history(history_no_init: dict, history_init: dict):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history_no_init['accuracy'], label='No shared init')
    plt.plot(history_init['accuracy'], label='Shared init')
    plt.title('Test accuracy')
    plt.xlabel('Round number')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history_no_init['loss'], label='No shared init')
    plt.plot(history_init['loss'], label='Shared init')
    plt.title('Test loss')
    plt.xlabel('Round number')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
display_history(history_no_init, history_init)

# %% [markdown]
# **Answer:**
# > As written in the paper, with shared initialization, averaging the models produces a significant reduction in the loss on the total training set. We can also see a faster convergence and higher final accuracy (with shared initialization).

# %% [markdown]
# ### 9. Reduce the number of data points in each sub-batch. What is the minimum number of data points necessary for the final model to have acceptable performance? Repeat the study on CIFAR-10

# %% [markdown]
# ### What is the minimum number of data points necessary for the final model to have acceptable performance?

# %%
def min_number_datapoints(federated_function: Callable, sizes: list = [50, 100, 200, 300, 400, 600]):
    results = {'size': [], 'accuracy': [], 'loss': []}

    for idx, size in enumerate(sizes):
        print(f"\n=== TEST {idx} with size={size} ===\n")
        history = federated_function(
            average_weight = [0.5, 0.5],
            num_rounds = 10,
            local_epochs = 5,
            shared_init = True,
            subset_size=size
        )

        results['size'].append(size)
        results['accuracy'].append(max(history['accuracy']))
        results['loss'].append(min(history['loss']))

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(results['size'], results['accuracy'], marker='o')
    plt.title('Best accuracy vs dataset size')
    plt.xlabel('Dataset size')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(results['size'], results['loss'], marker='o')
    plt.title('Best loss vs dataset size')
    plt.xlabel('Dataset size')
    plt.ylabel('Loss')

    plt.tight_layout()
    plt.show()

    return results

# %%
min_number_datapoints(federated_function=federated_averaging)
# Out:
# === TEST 0 with size=50 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.270, test_loss: 2.299, test_accuracy: 0.102,
# Training model 2 | train_loss: 2.288, test_loss: 2.298, test_accuracy: 0.129,
# -- Round 1 Federated Model --
# ==> test_loss = 2.298, test_accuracy = 0.102
#
# Training model 1 | train_loss: 2.247, test_loss: 2.292, test_accuracy: 0.121,
# Training model 2 | train_loss: 2.274, test_loss: 2.291, test_accuracy: 0.155,
# -- Round 2 Federated Model --
# ==> test_loss = 2.291, test_accuracy = 0.109
#
# Training model 1 | train_loss: 2.225, test_loss: 2.285, test_accuracy: 0.169,
# Training model 2 | train_loss: 2.260, test_loss: 2.284, test_accuracy: 0.210,
# -- Round 3 Federated Model --
# ==> test_loss = 2.284, test_accuracy = 0.167
#
# Training model 1 | train_loss: 2.204, test_loss: 2.280, test_accuracy: 0.224,
# Training model 2 | train_loss: 2.246, test_loss: 2.277, test_accuracy: 0.244,
# -- Round 4 Federated Model --
# ==> test_loss = 2.278, test_accuracy = 0.229
#
# Training model 1 | train_loss: 2.183, test_loss: 2.274, test_accuracy: 0.255,
# Training model 2 | train_loss: 2.233, test_loss: 2.271, test_accuracy: 0.229,
# -- Round 5 Federated Model --
# ==> test_loss = 2.272, test_accuracy = 0.240
#
# Training model 1 | train_loss: 2.161, test_loss: 2.269, test_accuracy: 0.250,
# Training model 2 | train_loss: 2.220, test_loss: 2.264, test_accuracy: 0.212,
# -- Round 6 Federated Model --
# ==> test_loss = 2.266, test_accuracy = 0.227
#
# Training model 1 | train_loss: 2.139, test_loss: 2.263, test_accuracy: 0.237,
# Training model 2 | train_loss: 2.206, test_loss: 2.258, test_accuracy: 0.208,
# -- Round 7 Federated Model --
# ==> test_loss = 2.259, test_accuracy = 0.216
#
# Training model 1 | train_loss: 2.117, test_loss: 2.258, test_accuracy: 0.227,
# Training model 2 | train_loss: 2.192, test_loss: 2.251, test_accuracy: 0.211,
# -- Round 8 Federated Model --
# ==> test_loss = 2.253, test_accuracy = 0.215
#
# Training model 1 | train_loss: 2.093, test_loss: 2.251, test_accuracy: 0.223,
# Training model 2 | train_loss: 2.177, test_loss: 2.243, test_accuracy: 0.216,
# -- Round 9 Federated Model --
# ==> test_loss = 2.246, test_accuracy = 0.222
#
# Training model 1 | train_loss: 2.069, test_loss: 2.244, test_accuracy: 0.228,
# Training model 2 | train_loss: 2.162, test_loss: 2.234, test_accuracy: 0.226,
# -- Round 10 Federated Model --
# ==> test_loss = 2.238, test_accuracy = 0.233
#
#
# === TEST 1 with size=100 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.269, test_loss: 2.301, test_accuracy: 0.098,
# Training model 2 | train_loss: 2.278, test_loss: 2.302, test_accuracy: 0.103,
# -- Round 1 Federated Model --
# ==> test_loss = 2.300, test_accuracy = 0.111
#
# Training model 1 | train_loss: 2.268, test_loss: 2.288, test_accuracy: 0.098,
# Training model 2 | train_loss: 2.231, test_loss: 2.289, test_accuracy: 0.103,
# -- Round 2 Federated Model --
# ==> test_loss = 2.287, test_accuracy = 0.158
#
# Training model 1 | train_loss: 2.226, test_loss: 2.275, test_accuracy: 0.099,
# Training model 2 | train_loss: 2.214, test_loss: 2.277, test_accuracy: 0.103,
# -- Round 3 Federated Model --
# ==> test_loss = 2.274, test_accuracy = 0.181
#
# Training model 1 | train_loss: 2.214, test_loss: 2.260, test_accuracy: 0.102,
# Training model 2 | train_loss: 2.195, test_loss: 2.263, test_accuracy: 0.109,
# -- Round 4 Federated Model --
# ==> test_loss = 2.259, test_accuracy = 0.190
#
# Training model 1 | train_loss: 2.192, test_loss: 2.243, test_accuracy: 0.107,
# Training model 2 | train_loss: 2.177, test_loss: 2.247, test_accuracy: 0.124,
# -- Round 5 Federated Model --
# ==> test_loss = 2.242, test_accuracy = 0.209
#
# Training model 1 | train_loss: 2.174, test_loss: 2.223, test_accuracy: 0.121,
# Training model 2 | train_loss: 2.142, test_loss: 2.227, test_accuracy: 0.150,
# -- Round 6 Federated Model --
# ==> test_loss = 2.222, test_accuracy = 0.244
#
# Training model 1 | train_loss: 2.122, test_loss: 2.199, test_accuracy: 0.178,
# Training model 2 | train_loss: 2.153, test_loss: 2.204, test_accuracy: 0.204,
# -- Round 7 Federated Model --
# ==> test_loss = 2.197, test_accuracy = 0.268
#
# Training model 1 | train_loss: 2.119, test_loss: 2.169, test_accuracy: 0.258,
# Training model 2 | train_loss: 2.037, test_loss: 2.176, test_accuracy: 0.260,
# -- Round 8 Federated Model --
# ==> test_loss = 2.167, test_accuracy = 0.290
#
# Training model 1 | train_loss: 2.085, test_loss: 2.134, test_accuracy: 0.312,
# Training model 2 | train_loss: 2.058, test_loss: 2.141, test_accuracy: 0.311,
# -- Round 9 Federated Model --
# ==> test_loss = 2.130, test_accuracy = 0.330
#
# Training model 1 | train_loss: 2.018, test_loss: 2.091, test_accuracy: 0.350,
# Training model 2 | train_loss: 1.940, test_loss: 2.097, test_accuracy: 0.336,
# -- Round 10 Federated Model --
# ==> test_loss = 2.084, test_accuracy = 0.376
#
#
# === TEST 2 with size=200 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.286, test_loss: 2.285, test_accuracy: 0.181,
# Training model 2 | train_loss: 2.278, test_loss: 2.287, test_accuracy: 0.098,
# -- Round 1 Federated Model --
# ==> test_loss = 2.286, test_accuracy = 0.149
#
# Training model 1 | train_loss: 2.253, test_loss: 2.260, test_accuracy: 0.198,
# Training model 2 | train_loss: 2.232, test_loss: 2.263, test_accuracy: 0.177,
# -- Round 2 Federated Model --
# ==> test_loss = 2.261, test_accuracy = 0.205
#
# Training model 1 | train_loss: 2.225, test_loss: 2.233, test_accuracy: 0.191,
# Training model 2 | train_loss: 2.210, test_loss: 2.235, test_accuracy: 0.191,
# -- Round 3 Federated Model --
# ==> test_loss = 2.233, test_accuracy = 0.193
#
# Training model 1 | train_loss: 2.173, test_loss: 2.196, test_accuracy: 0.209,
# Training model 2 | train_loss: 2.203, test_loss: 2.199, test_accuracy: 0.229,
# -- Round 4 Federated Model --
# ==> test_loss = 2.197, test_accuracy = 0.224
#
# Training model 1 | train_loss: 2.120, test_loss: 2.144, test_accuracy: 0.251,
# Training model 2 | train_loss: 2.147, test_loss: 2.148, test_accuracy: 0.297,
# -- Round 5 Federated Model --
# ==> test_loss = 2.145, test_accuracy = 0.273
#
# Training model 1 | train_loss: 2.022, test_loss: 2.070, test_accuracy: 0.323,
# Training model 2 | train_loss: 2.063, test_loss: 2.074, test_accuracy: 0.430,
# -- Round 6 Federated Model --
# ==> test_loss = 2.071, test_accuracy = 0.376
#
# Training model 1 | train_loss: 1.939, test_loss: 1.963, test_accuracy: 0.458,
# Training model 2 | train_loss: 1.947, test_loss: 1.968, test_accuracy: 0.609,
# -- Round 7 Federated Model --
# ==> test_loss = 1.964, test_accuracy = 0.549
#
# Training model 1 | train_loss: 1.720, test_loss: 1.813, test_accuracy: 0.605,
# Training model 2 | train_loss: 1.808, test_loss: 1.816, test_accuracy: 0.702,
# -- Round 8 Federated Model --
# ==> test_loss = 1.813, test_accuracy = 0.665
#
# Training model 1 | train_loss: 1.473, test_loss: 1.608, test_accuracy: 0.716,
# Training model 2 | train_loss: 1.625, test_loss: 1.608, test_accuracy: 0.758,
# -- Round 9 Federated Model --
# ==> test_loss = 1.606, test_accuracy = 0.747
#
# Training model 1 | train_loss: 1.315, test_loss: 1.369, test_accuracy: 0.774,
# Training model 2 | train_loss: 1.347, test_loss: 1.357, test_accuracy: 0.773,
# -- Round 10 Federated Model --
# ==> test_loss = 1.361, test_accuracy = 0.776
#
#
# === TEST 3 with size=300 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.268, test_loss: 2.264, test_accuracy: 0.227,
# Training model 2 | train_loss: 2.254, test_loss: 2.261, test_accuracy: 0.106,
# -- Round 1 Federated Model --
# ==> test_loss = 2.261, test_accuracy = 0.217
#
# Training model 1 | train_loss: 2.189, test_loss: 2.211, test_accuracy: 0.420,
# Training model 2 | train_loss: 2.194, test_loss: 2.206, test_accuracy: 0.153,
# -- Round 2 Federated Model --
# ==> test_loss = 2.207, test_accuracy = 0.392
#
# Training model 1 | train_loss: 2.089, test_loss: 2.127, test_accuracy: 0.483,
# Training model 2 | train_loss: 2.101, test_loss: 2.121, test_accuracy: 0.363,
# -- Round 3 Federated Model --
# ==> test_loss = 2.121, test_accuracy = 0.502
#
# Training model 1 | train_loss: 1.956, test_loss: 1.983, test_accuracy: 0.549,
# Training model 2 | train_loss: 2.005, test_loss: 1.969, test_accuracy: 0.597,
# -- Round 4 Federated Model --
# ==> test_loss = 1.971, test_accuracy = 0.613
#
# Training model 1 | train_loss: 1.639, test_loss: 1.721, test_accuracy: 0.630,
# Training model 2 | train_loss: 1.730, test_loss: 1.701, test_accuracy: 0.702,
# -- Round 5 Federated Model --
# ==> test_loss = 1.705, test_accuracy = 0.699
#
# Training model 1 | train_loss: 1.323, test_loss: 1.345, test_accuracy: 0.732,
# Training model 2 | train_loss: 1.224, test_loss: 1.306, test_accuracy: 0.771,
# -- Round 6 Federated Model --
# ==> test_loss = 1.321, test_accuracy = 0.760
#
# Training model 1 | train_loss: 1.120, test_loss: 0.989, test_accuracy: 0.792,
# Training model 2 | train_loss: 0.871, test_loss: 0.944, test_accuracy: 0.809,
# -- Round 7 Federated Model --
# ==> test_loss = 0.959, test_accuracy = 0.807
#
# Training model 1 | train_loss: 0.792, test_loss: 0.758, test_accuracy: 0.808,
# Training model 2 | train_loss: 0.751, test_loss: 0.738, test_accuracy: 0.821,
# -- Round 8 Federated Model --
# ==> test_loss = 0.734, test_accuracy = 0.826
#
# Training model 1 | train_loss: 0.527, test_loss: 0.652, test_accuracy: 0.816,
# Training model 2 | train_loss: 0.642, test_loss: 0.590, test_accuracy: 0.851,
# -- Round 9 Federated Model --
# ==> test_loss = 0.608, test_accuracy = 0.841
#
# Training model 1 | train_loss: 0.581, test_loss: 0.545, test_accuracy: 0.850,
# Training model 2 | train_loss: 0.547, test_loss: 0.509, test_accuracy: 0.863,
# -- Round 10 Federated Model --
# ==> test_loss = 0.515, test_accuracy = 0.861
#
#
# === TEST 4 with size=400 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.228, test_loss: 2.224, test_accuracy: 0.365,
# Training model 2 | train_loss: 2.214, test_loss: 2.230, test_accuracy: 0.179,
# -- Round 1 Federated Model --
# ==> test_loss = 2.225, test_accuracy = 0.366
#
# Training model 1 | train_loss: 2.072, test_loss: 2.096, test_accuracy: 0.482,
# Training model 2 | train_loss: 2.095, test_loss: 2.102, test_accuracy: 0.353,
# -- Round 2 Federated Model --
# ==> test_loss = 2.096, test_accuracy = 0.444
#
# Training model 1 | train_loss: 1.817, test_loss: 1.816, test_accuracy: 0.692,
# Training model 2 | train_loss: 1.799, test_loss: 1.830, test_accuracy: 0.498,
# -- Round 3 Federated Model --
# ==> test_loss = 1.819, test_accuracy = 0.632
#
# Training model 1 | train_loss: 1.431, test_loss: 1.342, test_accuracy: 0.782,
# Training model 2 | train_loss: 1.336, test_loss: 1.361, test_accuracy: 0.685,
# -- Round 4 Federated Model --
# ==> test_loss = 1.339, test_accuracy = 0.756
#
# Training model 1 | train_loss: 0.688, test_loss: 0.890, test_accuracy: 0.783,
# Training model 2 | train_loss: 0.930, test_loss: 0.898, test_accuracy: 0.785,
# -- Round 5 Federated Model --
# ==> test_loss = 0.881, test_accuracy = 0.804
#
# Training model 1 | train_loss: 0.645, test_loss: 0.639, test_accuracy: 0.843,
# Training model 2 | train_loss: 0.586, test_loss: 0.652, test_accuracy: 0.827,
# -- Round 6 Federated Model --
# ==> test_loss = 0.635, test_accuracy = 0.841
#
# Training model 1 | train_loss: 0.397, test_loss: 0.520, test_accuracy: 0.856,
# Training model 2 | train_loss: 0.456, test_loss: 0.528, test_accuracy: 0.845,
# -- Round 7 Federated Model --
# ==> test_loss = 0.515, test_accuracy = 0.856
#
# Training model 1 | train_loss: 0.329, test_loss: 0.462, test_accuracy: 0.863,
# Training model 2 | train_loss: 0.475, test_loss: 0.477, test_accuracy: 0.860,
# -- Round 8 Federated Model --
# ==> test_loss = 0.454, test_accuracy = 0.869
#
# Training model 1 | train_loss: 0.435, test_loss: 0.470, test_accuracy: 0.851,
# Training model 2 | train_loss: 0.468, test_loss: 0.427, test_accuracy: 0.875,
# -- Round 9 Federated Model --
# ==> test_loss = 0.423, test_accuracy = 0.876
#
# Training model 1 | train_loss: 0.304, test_loss: 0.386, test_accuracy: 0.883,
# Training model 2 | train_loss: 0.382, test_loss: 0.375, test_accuracy: 0.888,
# -- Round 10 Federated Model --
# ==> test_loss = 0.371, test_accuracy = 0.889
#
#
# === TEST 5 with size=600 ===
#
# ==> device used cuda
# Training model 1 | train_loss: 2.185, test_loss: 2.227, test_accuracy: 0.362,
# Training model 2 | train_loss: 2.217, test_loss: 2.232, test_accuracy: 0.305,
# -- Round 1 Federated Model --
# ==> test_loss = 2.227, test_accuracy = 0.540
#
# Training model 1 | train_loss: 1.989, test_loss: 2.043, test_accuracy: 0.501,
# Training model 2 | train_loss: 2.018, test_loss: 2.050, test_accuracy: 0.636,
# -- Round 2 Federated Model --
# ==> test_loss = 2.041, test_accuracy = 0.662
#
# Training model 1 | train_loss: 1.503, test_loss: 1.499, test_accuracy: 0.684,
# Training model 2 | train_loss: 1.393, test_loss: 1.509, test_accuracy: 0.771,
# -- Round 3 Federated Model --
# ==> test_loss = 1.499, test_accuracy = 0.754
#
# Training model 1 | train_loss: 0.918, test_loss: 0.825, test_accuracy: 0.843,
# Training model 2 | train_loss: 0.997, test_loss: 0.818, test_accuracy: 0.842,
# -- Round 4 Federated Model --
# ==> test_loss = 0.815, test_accuracy = 0.854
#
# Training model 1 | train_loss: 0.462, test_loss: 0.542, test_accuracy: 0.871,
# Training model 2 | train_loss: 0.513, test_loss: 0.523, test_accuracy: 0.877,
# -- Round 5 Federated Model --
# ==> test_loss = 0.525, test_accuracy = 0.877
#
# Training model 1 | train_loss: 0.265, test_loss: 0.421, test_accuracy: 0.891,
# Training model 2 | train_loss: 0.510, test_loss: 0.410, test_accuracy: 0.895,
# -- Round 6 Federated Model --
# ==> test_loss = 0.407, test_accuracy = 0.898
#
# Training model 1 | train_loss: 0.267, test_loss: 0.358, test_accuracy: 0.902,
# Training model 2 | train_loss: 0.307, test_loss: 0.347, test_accuracy: 0.907,
# -- Round 7 Federated Model --
# ==> test_loss = 0.346, test_accuracy = 0.907
#
# Training model 1 | train_loss: 0.320, test_loss: 0.351, test_accuracy: 0.893,
# Training model 2 | train_loss: 0.337, test_loss: 0.323, test_accuracy: 0.907,
# -- Round 8 Federated Model --
# ==> test_loss = 0.323, test_accuracy = 0.907
#
# Training model 1 | train_loss: 0.164, test_loss: 0.299, test_accuracy: 0.911,
# Training model 2 | train_loss: 0.165, test_loss: 0.290, test_accuracy: 0.919,
# -- Round 9 Federated Model --
# ==> test_loss = 0.288, test_accuracy = 0.917
#
# Training model 1 | train_loss: 0.236, test_loss: 0.289, test_accuracy: 0.912,
# Training model 2 | train_loss: 0.192, test_loss: 0.276, test_accuracy: 0.922,
# -- Round 10 Federated Model --
# ==> test_loss = 0.276, test_accuracy = 0.921
# {'size': [50, 100, 200, 300, 400, 600],
#  'accuracy': [0.2404, 0.3761, 0.7763, 0.8608, 0.8895, 0.9207],
#  'loss': [2.2376059532165526,
#   2.0838255405426027,
#   1.3608544588088989,
#   0.515036529302597,
#   0.3711216598749161,
#   0.2759631335735321]}

# %% [markdown]
# **Answer:**
# > For the MNIST dataset, the minimum number of data points necessary for acceptable model performance is between 300 and 400. At this range, the overall performance are close to the model with 600 data points (within 3-6% accuracy difference), with similar trends observed in the loss.

# %% [markdown]
# ###  Repeat the study on CIFAR-10
#
# #### Model definition

# %%
class CIFAR10CNN(nn.Module):
    def __init__(self, num_classes=10):
        super(CIFAR10CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.25)
        self.fc1 = nn.Linear(64 * 6 * 6, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.dropout(x)
        x = x.view(-1, 64 * 6 * 6)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #### Dataset loading and preprocessing

# %%
def get_cifar10_data():
    """Load and prepare CIFAR10 dataset"""
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),
        # ImageNet means and std init
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])

    train_dataset = torchvision.datasets.CIFAR10(
        root='./data',
        train=True,
        download=True,
        transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data',
        train=False,
        transform=transform,
        download=True,
    )

    return train_dataset, test_dataset

# %% [markdown]
# #### Custom training loop

# %%
def train_model(
    model: nn.Module, train_loader: DataLoader,
    epochs: int, device: str,
    learning_rate: float,
) -> float:
    """Train model and returns accuracy and loss"""
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
    model.train()

    for _ in range(epochs):
        for _, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

    return loss.item()

# %% [markdown]
# #### Federated averaging algorithm with custom CIFAR10 compliance functions

# %%
def cifar_federated_averaging(
    average_weight: list = [0.5, 0.5], subset_size: int = 6000,
    num_rounds: int = 10, local_epochs: int = 5,
    initial_lr: float = 0.01,
    shared_init: bool = True, device: str = device
):
    """Run federated learning experiment"""
    print(f"==> device used {device}")

    train_dataset, test_dataset = get_cifar10_data()
    train_loader_1, train_loader_2, test_loader = create_subsets(train_dataset, test_dataset, subset_size)

    # Models init
    models = [CIFAR10CNN().to(device), CIFAR10CNN().to(device)]
    training_loaders = [train_loader_1, train_loader_2]

    if shared_init:
        # same initialization for all models
        shared_params = models[0].state_dict()
        models[1].load_state_dict(shared_params)

    current_lr = initial_lr
    history = {'accuracy': [], 'loss': []}

    # Federated learning rounds
    for round_num in range(num_rounds):
        model_id = 1
        for model, t_loader in zip(models, training_loaders):
            loss = train_model(model, t_loader, local_epochs, device, current_lr)
            test_loss, t_accuracy = evaluate_model(model, test_loader, device)
            print(f"Training model {model_id} | train_loss: {loss:.3f}, test_loss: {test_loss:.3f}, test_accuracy: {t_accuracy:.3f}, ")
            model_id += 1

        # Average model parameters
        averaged_params = average_model_parameters(models, average_weight)

        # Update models with averaged parameters
        for model in models:
            update_model_parameters(model, averaged_params)

        # Evaluate global model
        test_loss, accuracy = evaluate_model(models[0], test_loader, device)
        history['loss'].append(test_loss)
        history['accuracy'].append(accuracy)

        print(f"-- Round {round_num + 1} Federated Model --\n==> test_loss = {test_loss:.3f}, test_accuracy = {accuracy:.3f}\n")

        current_lr *= 0.93

    return history

# %% [markdown]
# #### Models training with difference hyperparameters

# %%
history_no_init = cifar_federated_averaging(
    average_weight = [0.5, 0.5],
    subset_size = 6000,
    num_rounds = 10,
    local_epochs = 5,
    shared_init = False
)
# Out:
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.184, test_loss: 1.189, test_accuracy: 0.572,
# Training model 2 | train_loss: 0.874, test_loss: 1.196, test_accuracy: 0.570,
# -- Round 1 Federated Model --
# ==> test_loss = 2.170, test_accuracy = 0.208
#
# Training model 1 | train_loss: 0.949, test_loss: 1.091, test_accuracy: 0.619,
# Training model 2 | train_loss: 0.869, test_loss: 1.056, test_accuracy: 0.629,
# -- Round 2 Federated Model --
# ==> test_loss = 1.076, test_accuracy = 0.632
#
# Training model 1 | train_loss: 0.770, test_loss: 1.058, test_accuracy: 0.631,
# Training model 2 | train_loss: 0.642, test_loss: 0.995, test_accuracy: 0.653,
# -- Round 3 Federated Model --
# ==> test_loss = 0.940, test_accuracy = 0.678
#
# Training model 1 | train_loss: 0.844, test_loss: 0.990, test_accuracy: 0.659,
# Training model 2 | train_loss: 0.654, test_loss: 1.009, test_accuracy: 0.666,
# -- Round 4 Federated Model --
# ==> test_loss = 0.870, test_accuracy = 0.702
#
# Training model 1 | train_loss: 0.665, test_loss: 0.908, test_accuracy: 0.697,
# Training model 2 | train_loss: 0.430, test_loss: 0.918, test_accuracy: 0.688,
# -- Round 5 Federated Model --
# ==> test_loss = 0.817, test_accuracy = 0.716
#
# Training model 1 | train_loss: 0.354, test_loss: 0.918, test_accuracy: 0.697,
# Training model 2 | train_loss: 0.364, test_loss: 0.935, test_accuracy: 0.697,
# -- Round 6 Federated Model --
# ==> test_loss = 0.818, test_accuracy = 0.720
#
# Training model 1 | train_loss: 0.371, test_loss: 0.872, test_accuracy: 0.718,
# Training model 2 | train_loss: 0.399, test_loss: 0.881, test_accuracy: 0.711,
# -- Round 7 Federated Model --
# ==> test_loss = 0.800, test_accuracy = 0.734
#
# Training model 1 | train_loss: 0.390, test_loss: 0.915, test_accuracy: 0.711,
# Training model 2 | train_loss: 0.374, test_loss: 0.879, test_accuracy: 0.718,
# -- Round 8 Federated Model --
# ==> test_loss = 0.823, test_accuracy = 0.733
#
# Training model 1 | train_loss: 0.270, test_loss: 0.900, test_accuracy: 0.719,
# Training model 2 | train_loss: 0.252, test_loss: 0.877, test_accuracy: 0.724,
# -- Round 9 Federated Model --
# ==> test_loss = 0.809, test_accuracy = 0.738
#
# Training model 1 | train_loss: 0.177, test_loss: 0.905, test_accuracy: 0.726,
# Training model 2 | train_loss: 0.260, test_loss: 0.940, test_accuracy: 0.715,
# -- Round 10 Federated Model --
# ==> test_loss = 0.827, test_accuracy = 0.744

# %%
history_init = cifar_federated_averaging(
    average_weight = [0.5, 0.5],
    subset_size = 6000,
    num_rounds = 10,
    local_epochs = 5,
    shared_init = True,
)
# Out:
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.345, test_loss: 1.246, test_accuracy: 0.552,
# Training model 2 | train_loss: 1.079, test_loss: 1.229, test_accuracy: 0.556,
# -- Round 1 Federated Model --
# ==> test_loss = 1.308, test_accuracy = 0.569
#
# Training model 1 | train_loss: 0.962, test_loss: 1.083, test_accuracy: 0.620,
# Training model 2 | train_loss: 0.865, test_loss: 1.063, test_accuracy: 0.628,
# -- Round 2 Federated Model --
# ==> test_loss = 0.993, test_accuracy = 0.654
#
# Training model 1 | train_loss: 0.944, test_loss: 1.009, test_accuracy: 0.653,
# Training model 2 | train_loss: 0.728, test_loss: 1.004, test_accuracy: 0.659,
# -- Round 3 Federated Model --
# ==> test_loss = 0.912, test_accuracy = 0.685
#
# Training model 1 | train_loss: 0.587, test_loss: 0.932, test_accuracy: 0.684,
# Training model 2 | train_loss: 0.440, test_loss: 0.938, test_accuracy: 0.683,
# -- Round 4 Federated Model --
# ==> test_loss = 0.856, test_accuracy = 0.706
#
# Training model 1 | train_loss: 0.548, test_loss: 0.940, test_accuracy: 0.684,
# Training model 2 | train_loss: 0.513, test_loss: 0.959, test_accuracy: 0.682,
# -- Round 5 Federated Model --
# ==> test_loss = 0.835, test_accuracy = 0.714
#
# Training model 1 | train_loss: 0.489, test_loss: 0.926, test_accuracy: 0.698,
# Training model 2 | train_loss: 0.499, test_loss: 0.955, test_accuracy: 0.699,
# -- Round 6 Federated Model --
# ==> test_loss = 0.842, test_accuracy = 0.723
#
# Training model 1 | train_loss: 0.316, test_loss: 0.925, test_accuracy: 0.704,
# Training model 2 | train_loss: 0.385, test_loss: 0.925, test_accuracy: 0.708,
# -- Round 7 Federated Model --
# ==> test_loss = 0.837, test_accuracy = 0.730
#
# Training model 1 | train_loss: 0.329, test_loss: 0.949, test_accuracy: 0.708,
# Training model 2 | train_loss: 0.283, test_loss: 0.936, test_accuracy: 0.707,
# -- Round 8 Federated Model --
# ==> test_loss = 0.848, test_accuracy = 0.732
#
# Training model 1 | train_loss: 0.273, test_loss: 0.932, test_accuracy: 0.716,
# Training model 2 | train_loss: 0.421, test_loss: 0.937, test_accuracy: 0.711,
# -- Round 9 Federated Model --
# ==> test_loss = 0.850, test_accuracy = 0.731
#
# Training model 1 | train_loss: 0.243, test_loss: 0.923, test_accuracy: 0.721,
# Training model 2 | train_loss: 0.321, test_loss: 0.980, test_accuracy: 0.713,
# -- Round 10 Federated Model --
# ==> test_loss = 0.872, test_accuracy = 0.734

# %% [markdown]
# #### Comparision visualization between shared_init and no_shared_init

# %%
display_history(history_no_init, history_init)

# %% [markdown]
# **Answer**
# > My implementation of the federated approach showed less advantage on CIFAR-10. While convergence remains faster, the final accuracy/loss is the same. This can be attributed to CIFAR-10 being more challenging to train than MNIST. It's is also important to note that the original paper tested this with 100 different models on 600 datapoints each.

# %% [markdown]
# #### What is the minimum number of data points necessary for the final model to have acceptable performance?

# %%
min_number_datapoints(
    federated_function=cifar_federated_averaging,
    sizes = [500, 1000, 2000, 3000, 4000, 6000]
)
# Out:
# === TEST 0 with size=500 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.825, test_loss: 1.794, test_accuracy: 0.366,
# Training model 2 | train_loss: 1.709, test_loss: 1.769, test_accuracy: 0.358,
# -- Round 1 Federated Model --
# ==> test_loss = 1.647, test_accuracy = 0.393
#
# Training model 1 | train_loss: 1.136, test_loss: 1.706, test_accuracy: 0.392,
# Training model 2 | train_loss: 1.003, test_loss: 1.746, test_accuracy: 0.398,
# -- Round 2 Federated Model --
# ==> test_loss = 1.527, test_accuracy = 0.439
#
# Training model 1 | train_loss: 0.885, test_loss: 1.851, test_accuracy: 0.370,
# Training model 2 | train_loss: 0.794, test_loss: 1.627, test_accuracy: 0.444,
# -- Round 3 Federated Model --
# ==> test_loss = 1.538, test_accuracy = 0.447
#
# Training model 1 | train_loss: 0.759, test_loss: 1.796, test_accuracy: 0.420,
# Training model 2 | train_loss: 0.733, test_loss: 1.954, test_accuracy: 0.387,
# -- Round 4 Federated Model --
# ==> test_loss = 1.552, test_accuracy = 0.466
#
# Training model 1 | train_loss: 0.566, test_loss: 1.792, test_accuracy: 0.433,
# Training model 2 | train_loss: 0.556, test_loss: 1.808, test_accuracy: 0.445,
# -- Round 5 Federated Model --
# ==> test_loss = 1.589, test_accuracy = 0.474
#
# Training model 1 | train_loss: 0.504, test_loss: 1.841, test_accuracy: 0.443,
# Training model 2 | train_loss: 0.511, test_loss: 1.771, test_accuracy: 0.463,
# -- Round 6 Federated Model --
# ==> test_loss = 1.611, test_accuracy = 0.492
#
# Training model 1 | train_loss: 0.399, test_loss: 1.826, test_accuracy: 0.461,
# Training model 2 | train_loss: 0.321, test_loss: 1.754, test_accuracy: 0.478,
# -- Round 7 Federated Model --
# ==> test_loss = 1.655, test_accuracy = 0.490
#
# Training model 1 | train_loss: 0.262, test_loss: 1.993, test_accuracy: 0.442,
# Training model 2 | train_loss: 0.319, test_loss: 1.815, test_accuracy: 0.483,
# -- Round 8 Federated Model --
# ==> test_loss = 1.722, test_accuracy = 0.487
#
# Training model 1 | train_loss: 0.318, test_loss: 1.893, test_accuracy: 0.465,
# Training model 2 | train_loss: 0.246, test_loss: 1.837, test_accuracy: 0.476,
# -- Round 9 Federated Model --
# ==> test_loss = 1.725, test_accuracy = 0.491
#
# Training model 1 | train_loss: 0.192, test_loss: 1.850, test_accuracy: 0.474,
# Training model 2 | train_loss: 0.208, test_loss: 1.838, test_accuracy: 0.491,
# -- Round 10 Federated Model --
# ==> test_loss = 1.719, test_accuracy = 0.502
#
#
# === TEST 1 with size=1000 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.327, test_loss: 1.584, test_accuracy: 0.430,
# Training model 2 | train_loss: 1.699, test_loss: 1.628, test_accuracy: 0.399,
# -- Round 1 Federated Model --
# ==> test_loss = 1.569, test_accuracy = 0.429
#
# Training model 1 | train_loss: 1.147, test_loss: 1.542, test_accuracy: 0.453,
# Training model 2 | train_loss: 1.311, test_loss: 1.588, test_accuracy: 0.447,
# -- Round 2 Federated Model --
# ==> test_loss = 1.355, test_accuracy = 0.498
#
# Training model 1 | train_loss: 1.194, test_loss: 1.518, test_accuracy: 0.486,
# Training model 2 | train_loss: 0.897, test_loss: 1.522, test_accuracy: 0.488,
# -- Round 3 Federated Model --
# ==> test_loss = 1.351, test_accuracy = 0.521
#
# Training model 1 | train_loss: 0.773, test_loss: 1.417, test_accuracy: 0.516,
# Training model 2 | train_loss: 0.719, test_loss: 1.459, test_accuracy: 0.518,
# -- Round 4 Federated Model --
# ==> test_loss = 1.301, test_accuracy = 0.546
#
# Training model 1 | train_loss: 0.736, test_loss: 1.446, test_accuracy: 0.532,
# Training model 2 | train_loss: 0.594, test_loss: 1.501, test_accuracy: 0.520,
# -- Round 5 Federated Model --
# ==> test_loss = 1.295, test_accuracy = 0.562
#
# Training model 1 | train_loss: 0.579, test_loss: 1.522, test_accuracy: 0.520,
# Training model 2 | train_loss: 0.546, test_loss: 1.500, test_accuracy: 0.542,
# -- Round 6 Federated Model --
# ==> test_loss = 1.332, test_accuracy = 0.570
#
# Training model 1 | train_loss: 0.280, test_loss: 1.532, test_accuracy: 0.545,
# Training model 2 | train_loss: 0.201, test_loss: 1.585, test_accuracy: 0.533,
# -- Round 7 Federated Model --
# ==> test_loss = 1.389, test_accuracy = 0.575
#
# Training model 1 | train_loss: 0.314, test_loss: 1.503, test_accuracy: 0.559,
# Training model 2 | train_loss: 0.238, test_loss: 1.506, test_accuracy: 0.558,
# -- Round 8 Federated Model --
# ==> test_loss = 1.360, test_accuracy = 0.585
#
# Training model 1 | train_loss: 0.232, test_loss: 1.474, test_accuracy: 0.566,
# Training model 2 | train_loss: 0.291, test_loss: 1.566, test_accuracy: 0.546,
# -- Round 9 Federated Model --
# ==> test_loss = 1.374, test_accuracy = 0.579
#
# Training model 1 | train_loss: 0.118, test_loss: 1.552, test_accuracy: 0.567,
# Training model 2 | train_loss: 0.134, test_loss: 1.608, test_accuracy: 0.560,
# -- Round 10 Federated Model --
# ==> test_loss = 1.455, test_accuracy = 0.579
#
#
# === TEST 2 with size=2000 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.472, test_loss: 1.659, test_accuracy: 0.422,
# Training model 2 | train_loss: 1.430, test_loss: 1.547, test_accuracy: 0.443,
# -- Round 1 Federated Model --
# ==> test_loss = 1.546, test_accuracy = 0.453
#
# Training model 1 | train_loss: 1.284, test_loss: 1.365, test_accuracy: 0.512,
# Training model 2 | train_loss: 1.004, test_loss: 1.332, test_accuracy: 0.520,
# -- Round 2 Federated Model --
# ==> test_loss = 1.263, test_accuracy = 0.551
#
# Training model 1 | train_loss: 1.006, test_loss: 1.332, test_accuracy: 0.538,
# Training model 2 | train_loss: 0.927, test_loss: 1.333, test_accuracy: 0.529,
# -- Round 3 Federated Model --
# ==> test_loss = 1.171, test_accuracy = 0.582
#
# Training model 1 | train_loss: 0.807, test_loss: 1.234, test_accuracy: 0.582,
# Training model 2 | train_loss: 0.424, test_loss: 1.305, test_accuracy: 0.566,
# -- Round 4 Federated Model --
# ==> test_loss = 1.132, test_accuracy = 0.605
#
# Training model 1 | train_loss: 0.392, test_loss: 1.294, test_accuracy: 0.569,
# Training model 2 | train_loss: 0.421, test_loss: 1.209, test_accuracy: 0.601,
# -- Round 5 Federated Model --
# ==> test_loss = 1.118, test_accuracy = 0.621
#
# Training model 1 | train_loss: 0.548, test_loss: 1.304, test_accuracy: 0.592,
# Training model 2 | train_loss: 0.495, test_loss: 1.324, test_accuracy: 0.590,
# -- Round 6 Federated Model --
# ==> test_loss = 1.183, test_accuracy = 0.616
#
# Training model 1 | train_loss: 0.547, test_loss: 1.293, test_accuracy: 0.598,
# Training model 2 | train_loss: 0.454, test_loss: 1.231, test_accuracy: 0.613,
# -- Round 7 Federated Model --
# ==> test_loss = 1.136, test_accuracy = 0.636
#
# Training model 1 | train_loss: 0.273, test_loss: 1.282, test_accuracy: 0.616,
# Training model 2 | train_loss: 0.332, test_loss: 1.285, test_accuracy: 0.625,
# -- Round 8 Federated Model --
# ==> test_loss = 1.177, test_accuracy = 0.639
#
# Training model 1 | train_loss: 0.342, test_loss: 1.280, test_accuracy: 0.613,
# Training model 2 | train_loss: 0.327, test_loss: 1.288, test_accuracy: 0.627,
# -- Round 9 Federated Model --
# ==> test_loss = 1.185, test_accuracy = 0.642
#
# Training model 1 | train_loss: 0.371, test_loss: 1.312, test_accuracy: 0.619,
# Training model 2 | train_loss: 0.180, test_loss: 1.348, test_accuracy: 0.619,
# -- Round 10 Federated Model --
# ==> test_loss = 1.203, test_accuracy = 0.646
#
#
# === TEST 3 with size=3000 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.170, test_loss: 1.521, test_accuracy: 0.453,
# Training model 2 | train_loss: 1.201, test_loss: 1.378, test_accuracy: 0.503,
# -- Round 1 Federated Model --
# ==> test_loss = 1.396, test_accuracy = 0.517
#
# Training model 1 | train_loss: 0.943, test_loss: 1.260, test_accuracy: 0.553,
# Training model 2 | train_loss: 0.705, test_loss: 1.268, test_accuracy: 0.556,
# -- Round 2 Federated Model --
# ==> test_loss = 1.166, test_accuracy = 0.591
#
# Training model 1 | train_loss: 0.814, test_loss: 1.203, test_accuracy: 0.581,
# Training model 2 | train_loss: 0.915, test_loss: 1.214, test_accuracy: 0.579,
# -- Round 3 Federated Model --
# ==> test_loss = 1.075, test_accuracy = 0.623
#
# Training model 1 | train_loss: 0.477, test_loss: 1.092, test_accuracy: 0.630,
# Training model 2 | train_loss: 0.625, test_loss: 1.143, test_accuracy: 0.621,
# -- Round 4 Federated Model --
# ==> test_loss = 1.022, test_accuracy = 0.650
#
# Training model 1 | train_loss: 0.570, test_loss: 1.197, test_accuracy: 0.620,
# Training model 2 | train_loss: 0.417, test_loss: 1.168, test_accuracy: 0.623,
# -- Round 5 Federated Model --
# ==> test_loss = 1.056, test_accuracy = 0.652
#
# Training model 1 | train_loss: 0.392, test_loss: 1.170, test_accuracy: 0.629,
# Training model 2 | train_loss: 0.447, test_loss: 1.089, test_accuracy: 0.642,
# -- Round 6 Federated Model --
# ==> test_loss = 1.008, test_accuracy = 0.667
#
# Training model 1 | train_loss: 0.340, test_loss: 1.137, test_accuracy: 0.652,
# Training model 2 | train_loss: 0.476, test_loss: 1.109, test_accuracy: 0.647,
# -- Round 7 Federated Model --
# ==> test_loss = 1.042, test_accuracy = 0.667
#
# Training model 1 | train_loss: 0.260, test_loss: 1.131, test_accuracy: 0.654,
# Training model 2 | train_loss: 0.224, test_loss: 1.133, test_accuracy: 0.652,
# -- Round 8 Federated Model --
# ==> test_loss = 1.025, test_accuracy = 0.677
#
# Training model 1 | train_loss: 0.387, test_loss: 1.117, test_accuracy: 0.666,
# Training model 2 | train_loss: 0.244, test_loss: 1.168, test_accuracy: 0.657,
# -- Round 9 Federated Model --
# ==> test_loss = 1.044, test_accuracy = 0.679
#
# Training model 1 | train_loss: 0.141, test_loss: 1.138, test_accuracy: 0.664,
# Training model 2 | train_loss: 0.169, test_loss: 1.135, test_accuracy: 0.665,
# -- Round 10 Federated Model --
# ==> test_loss = 1.049, test_accuracy = 0.682
#
#
# === TEST 4 with size=4000 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.136, test_loss: 1.320, test_accuracy: 0.523,
# Training model 2 | train_loss: 1.223, test_loss: 1.340, test_accuracy: 0.515,
# -- Round 1 Federated Model --
# ==> test_loss = 1.385, test_accuracy = 0.522
#
# Training model 1 | train_loss: 0.844, test_loss: 1.156, test_accuracy: 0.584,
# Training model 2 | train_loss: 0.855, test_loss: 1.196, test_accuracy: 0.575,
# -- Round 2 Federated Model --
# ==> test_loss = 1.118, test_accuracy = 0.601
#
# Training model 1 | train_loss: 1.001, test_loss: 1.090, test_accuracy: 0.619,
# Training model 2 | train_loss: 0.871, test_loss: 1.097, test_accuracy: 0.619,
# -- Round 3 Federated Model --
# ==> test_loss = 1.000, test_accuracy = 0.651
#
# Training model 1 | train_loss: 0.521, test_loss: 1.065, test_accuracy: 0.645,
# Training model 2 | train_loss: 0.736, test_loss: 1.091, test_accuracy: 0.626,
# -- Round 4 Federated Model --
# ==> test_loss = 0.976, test_accuracy = 0.662
#
# Training model 1 | train_loss: 0.679, test_loss: 1.111, test_accuracy: 0.647,
# Training model 2 | train_loss: 0.606, test_loss: 1.016, test_accuracy: 0.658,
# -- Round 5 Federated Model --
# ==> test_loss = 0.948, test_accuracy = 0.677
#
# Training model 1 | train_loss: 0.629, test_loss: 1.028, test_accuracy: 0.666,
# Training model 2 | train_loss: 0.601, test_loss: 1.092, test_accuracy: 0.646,
# -- Round 6 Federated Model --
# ==> test_loss = 0.955, test_accuracy = 0.679
#
# Training model 1 | train_loss: 0.298, test_loss: 1.079, test_accuracy: 0.669,
# Training model 2 | train_loss: 0.348, test_loss: 1.059, test_accuracy: 0.669,
# -- Round 7 Federated Model --
# ==> test_loss = 0.973, test_accuracy = 0.692
#
# Training model 1 | train_loss: 0.381, test_loss: 1.026, test_accuracy: 0.680,
# Training model 2 | train_loss: 0.297, test_loss: 1.041, test_accuracy: 0.679,
# -- Round 8 Federated Model --
# ==> test_loss = 0.951, test_accuracy = 0.700
#
# Training model 1 | train_loss: 0.201, test_loss: 1.057, test_accuracy: 0.683,
# Training model 2 | train_loss: 0.247, test_loss: 1.123, test_accuracy: 0.671,
# -- Round 9 Federated Model --
# ==> test_loss = 0.996, test_accuracy = 0.695
#
# Training model 1 | train_loss: 0.285, test_loss: 1.077, test_accuracy: 0.683,
# Training model 2 | train_loss: 0.161, test_loss: 1.087, test_accuracy: 0.685,
# -- Round 10 Federated Model --
# ==> test_loss = 1.006, test_accuracy = 0.698
#
#
# === TEST 5 with size=6000 ===
#
# ==> device used cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training model 1 | train_loss: 1.278, test_loss: 1.329, test_accuracy: 0.526,
# Training model 2 | train_loss: 1.294, test_loss: 1.234, test_accuracy: 0.557,
# -- Round 1 Federated Model --
# ==> test_loss = 1.350, test_accuracy = 0.560
#
# Training model 1 | train_loss: 0.797, test_loss: 1.046, test_accuracy: 0.632,
# Training model 2 | train_loss: 1.001, test_loss: 1.065, test_accuracy: 0.626,
# -- Round 2 Federated Model --
# ==> test_loss = 0.994, test_accuracy = 0.649
#
# Training model 1 | train_loss: 1.043, test_loss: 1.019, test_accuracy: 0.645,
# Training model 2 | train_loss: 0.942, test_loss: 1.025, test_accuracy: 0.643,
# -- Round 3 Federated Model --
# ==> test_loss = 0.923, test_accuracy = 0.679
#
# Training model 1 | train_loss: 0.617, test_loss: 0.929, test_accuracy: 0.683,
# Training model 2 | train_loss: 0.441, test_loss: 0.954, test_accuracy: 0.681,
# -- Round 4 Federated Model --
# ==> test_loss = 0.851, test_accuracy = 0.711
#
# Training model 1 | train_loss: 0.454, test_loss: 0.949, test_accuracy: 0.689,
# Training model 2 | train_loss: 0.521, test_loss: 0.935, test_accuracy: 0.693,
# -- Round 5 Federated Model --
# ==> test_loss = 0.866, test_accuracy = 0.710
#
# Training model 1 | train_loss: 0.441, test_loss: 0.920, test_accuracy: 0.700,
# Training model 2 | train_loss: 0.450, test_loss: 0.946, test_accuracy: 0.699,
# -- Round 6 Federated Model --
# ==> test_loss = 0.838, test_accuracy = 0.724
#
# Training model 1 | train_loss: 0.331, test_loss: 0.931, test_accuracy: 0.700,
# Training model 2 | train_loss: 0.699, test_loss: 0.917, test_accuracy: 0.704,
# -- Round 7 Federated Model --
# ==> test_loss = 0.849, test_accuracy = 0.722
#
# Training model 1 | train_loss: 0.274, test_loss: 0.954, test_accuracy: 0.706,
# Training model 2 | train_loss: 0.193, test_loss: 0.921, test_accuracy: 0.711,
# -- Round 8 Federated Model --
# ==> test_loss = 0.836, test_accuracy = 0.734
#
# Training model 1 | train_loss: 0.370, test_loss: 0.917, test_accuracy: 0.711,
# Training model 2 | train_loss: 0.146, test_loss: 0.901, test_accuracy: 0.718,
# -- Round 9 Federated Model --
# ==> test_loss = 0.837, test_accuracy = 0.735
#
# Training model 1 | train_loss: 0.465, test_loss: 0.942, test_accuracy: 0.716,
# Training model 2 | train_loss: 0.227, test_loss: 0.906, test_accuracy: 0.721,
# -- Round 10 Federated Model --
# ==> test_loss = 0.838, test_accuracy = 0.741
# {'size': [500, 1000, 2000, 3000, 4000, 6000],
#  'accuracy': [0.5022, 0.5846, 0.6465, 0.6825, 0.6997, 0.7412],
#  'loss': [1.5273302435874938,
#   1.2952759742736817,
#   1.1184809923171997,
#   1.007759416103363,
#   0.9477048575878143,
#   0.8360423862934112]}

# %% [markdown]
# **Answer**
# > The overall performance peaks around 0.75 accuracy. Reducing the dataset from 6000 to 4000 datapoints drops the accuracy from 0.75 to 0.7, with further reductions leading to significant performance degradation.
